# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Алёна, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Кажется, недоделанный проект был отправлен случайно? Поправь, пожалуйста, чтобы я смог целостно и качественно проверить твою работу

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# Сейчас аналогично отсутствуют шаги задани. Если имеются сложности в реализации проекта, то рекомендую обратиться к преподавателю по проектам ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Я уже не знаю что делать и как отправить вам мою работу.
#     Я написала куратору Дарье, она сказала обратиться к преподавателю, Иван Копьев направил меня на техподдержку, техподдержка спросила связывалась ли я с куратором, я ответила "ДА". Все и техподдержка больше мне ничего не отвечает.
#     Я заполнила заново все задания. Прикладываю скрин части заданий, добавлю ссылку на работу. Может быть каким-нибудь еще другим способом можно вам отправить задания на проверку?
#  Ссылка https://practicum.yandex.ru/trainer/data-scientist/lesson/b689e788-5b12-464d-9438-af0736e3047d/jupyter-homework/
#
#  ![image.png](attachment:image.png)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Вероятнее всего делала проект локально, и при прогрузке не получилось прислать актуальный (а лишь шаблон). Се5йчас вижу проект, приступаю к ревью

# %% [markdown]
# # Анализ лояльности пользователей Яндекс Афиши

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# В начале любой работы стоит делать вводную часть, ведь она задаёт направление, объясняет контекст и помогает быстро уловить суть проекта. Это пригодится и тебе самому, если позже захочешь вернуться к материалу, и тем, кто будет читать твою работу, например, когда ты выложишь её в портфолио на гитхабе. Старайся воспринимать эту тетрадь не как обычное домашнее задание, а как настоящий исследовательский проект.
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
#
# Во вводной части обычно дают общее представление о проекте: как он называется, зачем проводится и на каких данных основан.  Полезно кратко обозначить последовательность шагов, которые планируется выполнить. По сути, задача этой части это сразу показать суть проекта

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
#
# **Цель проекта**
#
# Данный проект посвящен анализу лояльности пользователей платформы Яндекс Афиша. **Цель исследования** — выявить ключевые факторы, влияющие на удержание и активность аудитории, а также определить сегменты наиболее лояльных пользователей. Анализ основан на данных о поведении пользователей, их взаимодействии с контентом, покупках билетов и участии в мероприятиях, собранных за определенный период.
#
# **Основная задача проекта** — разработать модель оценки лояльности, а также выявить закономерности и паттерны поведения, способствующие увеличению удержания аудитории. Для достижения цели планируется выполнить следующие **шаги**: сбор и предварительная обработка данных, построение аналитических моделей, оценка факторов, влияющих на лояльность, и формирование рекомендаций по повышению уровня удержания пользователей.
#
# Данный анализ поможет лучше понять поведение аудитории, повысить эффективность маркетинговых стратегий и улучшить пользовательский опыт на платформе Яндекс Афиша.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# ## Этапы выполнения проекта
#
# ### 1. Загрузка данных и их предобработка
#
# ---
#
# **Задача 1.1:** Напишите SQL-запрос, выгружающий в датафрейм pandas необходимые данные.
#
# Для выгрузки используйте запрос из предыдущего урока и библиотеку SQLAlchemy.
#
# Выгрузка из базы данных SQL должна позволить собрать следующие данные:
#
# - `user_id` — уникальный идентификатор пользователя, совершившего заказ;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ (`mobile` — мобильные устройства, `desktop` — стационарные);
# - `order_id` — уникальный идентификатор заказа;
# - `order_dt` — дата создания заказа (используйте данные `created_dt_msk`);
# - `order_ts` — дата и время создания заказа (используйте данные `created_ts_msk`);
# - `currency_code` — валюта оплаты;
# - `revenue` — выручка от заказа;
# - `tickets_count` — количество купленных билетов;
# - `days_since_prev` — количество дней от предыдущей покупки пользователя, для пользователей с одной покупкой — значение пропущено;
# - `event_id` — уникальный идентификатор мероприятия;
# - `service_name` — название билетного оператора;
# - `event_type_main` — основной тип мероприятия (театральная постановка, концерт и так далее);
# - `region_name` — название региона, в котором прошло мероприятие;
# - `city_name` — название города, в котором прошло мероприятие.
#
# ---

# %%
# Используйте ячейки типа Code для вашего кода,
# а ячейки типа Markdown для комментариев и выводов

# %%
# При необходимости добавляйте новые ячейки для кода или текста

# %%
# !pip install sqlalchemy
# !pip install dotenv
# !pip install psycopg2-binary
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import os
import dotenv

# Загружаем переменные окружения из файла .env
dotenv.load_dotenv()

# создаем строку подключения, используя os.getenv()
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    os.getenv('DB_USER'),
    os.getenv('DB_PASSWORD'),
    os.getenv('DB_HOST'),
    os.getenv('DB_PORT'),
    os.getenv('DB_NAME'),
)

# создаем движок SQLAlchemy
engine = create_engine(connection_string)

# создаем строку подключения
#engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
#engine = create_engine(f'postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}')
sql_query = """
select
user_id, 
device_type_canonical, 
order_id, 
created_dt_msk as order_dt, 
created_ts_msk as order_ts, 
currency_code, 
revenue, 
tickets_count, 
extract(
        day FROM (
            created_dt_msk - lag(created_dt_msk::date) OVER (PARTITION BY user_id ORDER BY created_dt_msk)
        )
    ) AS days_since_prev,
e.event_id, 
event_name_code, 
service_name, 
event_type_main, 
r.region_name,
c.city_name 
FROM afisha.purchases as p
LEFT JOIN afisha.events e  ON (p.event_id = e.event_id)
LEFT JOIN afisha.city c ON (e.city_id=c.city_id)
LEFT JOIN afisha.regions r ON (c.region_id=r.region_id)
WHERE p.device_type_canonical IN ('mobile', 'desktop')
AND e.event_type_main <> 'фильм'
ORDER BY
p.user_id ASC,
p.created_dt_msk ASC;
"""
df = pd.read_sql(sql_query, engine)
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------------------- -------------------- 1.3/2.7 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 4.7 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 2.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Все необходимые библиотеки стоит выгружать в начале проекта в одной ячейке кода. Чтобы сразу видеть, какие модули используются в проекте

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
# Сейчас ты явным образом прописываешь параметры подключения к БД. В таком виде выкладывать работу в публичный доступ небезопасно, кто-то сможет завладеть подключением, украсть или повредить данные.
#
# Чтобы засекретить подключение, необходимо сложить все параметры в `.env` файл (или другой конфигурационный файл вне Git) и указать его в `.gitignore`:
#
# ```python
# DB_NAME="..."
# DB_HOST="..."
# DB_PORT="..."
# DB_USER="..."
# DB_PASSWORD="..."
# ```
#
# В самом проекте мы можем обращаться к сохраненным параметрам, для этого нам потребуются библиотеки `dotenv`, чтобы загрузить переменные окружения, и `os`, чтобы обратиться к ним:
#
# ```python
# import os
# import dotenv
#
# load_dotenv() # автоматически ищет .env в текущей директории
#
# connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
#     os.getenv('DB_USER'),
#     os.getenv('DB_PASSWORD'),
#     os.getenv('DB_HOST'),
#     os.getenv('DB_PORT'),
#     os.getenv('DB_NAME'),
# )
# ```
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# На гитхабе так нужно организовать обязательно, для принятия проекта.

# %% [markdown]
# ---
#
# **Задача 1.2:** Изучите общую информацию о выгруженных данных. Оцените корректность выгрузки и объём полученных данных.
#
# Предположите, какие шаги необходимо сделать на стадии предобработки данных — например, скорректировать типы данных.
#
# Зафиксируйте основную информацию о данных в кратком промежуточном выводе.
#
# ---

# %%
# Выводим информацию о датафрейме
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  datetime64[ns]
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name_code        290611 non-null  object
#  11  service_name           290611 non-null  object
#  12  event_type_main        290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %%
# Выводим первые строки датафрейма на экран
df.head()
# Out:
#            user_id device_type_canonical  order_id   order_dt  \
# 0  0002849b70a3ce2                mobile   4359165 2024-08-20
# 1  0005ca5e93f2cf4                mobile   7965605 2024-07-23
# 2  0005ca5e93f2cf4                mobile   7292370 2024-10-06
# 3  000898990054619                mobile   1139875 2024-07-13
# 4  000898990054619                mobile    972400 2024-10-04
#
#              order_ts currency_code  revenue  tickets_count  days_since_prev  \
# 0 2024-08-20 16:08:03           rub  1521.94              4              NaN
# 1 2024-07-23 18:36:24           rub   289.45              2              NaN
# 2 2024-10-06 13:56:02           rub  1258.57              4             75.0
# 3 2024-07-13 19:40:48           rub     8.49              2              NaN
# 4 2024-10-04 22:33:15           rub  1390.41              3             83.0
#
#    event_id                       event_name_code        service_name  \
# ...

# %% [markdown]
# **Вывод**
#
# Датасет содержит 14 столбцов и 290611 строк, в которых представлена информация о заказах билетов.
#
# После первичного анализа данных можно сделать следующие выводы:
#
# Названия столбцов все приведены к одному виду - snake case. Большая часть данных содержит текстовые значения и хранятся в типе данных object. Значения в столбцах `order_id` (номер заказа), `tickets_count` (количество купленных билетов) и `event_id` (идентификатор мероприятия) представлены целыми числами. В столбце `revenue` данные хранятся в типе float64, это и понятно, т.к. сумма выручки от заказа может быть не целочисленным значением. Стоит обратить внимание на столбец `days_since_prev`, в нем есть пропуски. Значения в столбцах соответствуют своему описанию.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
#
# Не совсем понятна фраза "Судя по первому знакомству с данными, значения в столбцах соответствуют своему описанию.". Как думаешь, с чем связаны пропуски?

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
#
# Пропуски в столбце `days_since_prev` могут быть связаны с несколькими причинами:
#  - Первый заказ пользователя: Для новых или впервые зарегистрировавшихся пользователей, не имеющих предыдущих покупок, значение этого столбца обычно отсутствует или равно нулю, что интерпретируется как пропуск.
#  - Отсутствие повторных покупок: Если пользователь совершает только один заказ за весь период анализа, то для него не будет значения в этом столбце после этой покупки, поскольку предыдущая покупка отсутствует.
#  - Ошибки или неполнота данных: Пропуски могут возникать из-за ошибок в сборе данных, например, если какие-то транзакции не были зафиксированы или есть пропуски в датах покупок.
#  - Фильтрация данных: В ходе подготовки данных могли быть исключены некоторые транзакции или пользователи, что также могло привести к пропускам в этом столбце.
# Таким образом, пропуски в этом столбце в основном связаны с отсутствием предыдущих покупок у пользователя или с особенностями сбора и обработки данных.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Вероятнее всего, это связано с тем, что данные записи относятся к первым покупкам клиентов.

# %% [markdown]
# ---
#
# ###  2. Предобработка данных
#
# Выполните все стандартные действия по предобработке данных:
#
# ---
#
# **Задача 2.1:** Данные о выручке сервиса представлены в российских рублях и казахстанских тенге. Приведите выручку к единой валюте — российскому рублю.
#
# Для этого используйте датасет с информацией о курсе казахстанского тенге по отношению к российскому рублю за 2024 год — `final_tickets_tenge_df.csv`. Его можно загрузить по пути `https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')`
#
# Значения в рублях представлено для 100 тенге.
#
# Результаты преобразования сохраните в новый столбец `revenue_rub`.
#
# ---

# %%
# Выгружаем информацию о курсе казахстанского тенге
kurs_df = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')
# Выводим первые строки датафрейма на экран
kurs_df.head()
# Out:
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %%
#подготовка главного df: дату заказа
df['order_dt'] = pd.to_datetime(df['order_dt']).dt.date

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290611 entries, 0 to 290610
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  object
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name_code        290611 non-null  object
#  11  service_name           290611 non-null  object
#  12  event_type_main        290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %%
# привести дату к типу date\n",
kurs_df['data'] = pd.to_datetime(kurs_df['data']).dt.date

#объединение по дате (date — kurs_dfDate; order_dt —  заказ)
df = df.merge(kurs_df[['data', 'curs']], left_on='order_dt', right_on='data', how='left')

#вычисление revenue_rub
df['revenue_rub'] = df['revenue']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290611 entries, 0 to 290610
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                290611 non-null  object
#  1   device_type_canonical  290611 non-null  object
#  2   order_id               290611 non-null  int64
#  3   order_dt               290611 non-null  object
#  4   order_ts               290611 non-null  datetime64[ns]
#  5   currency_code          290611 non-null  object
#  6   revenue                290611 non-null  float64
#  7   tickets_count          290611 non-null  int64
#  8   days_since_prev        268678 non-null  float64
#  9   event_id               290611 non-null  int64
#  10  event_name_code        290611 non-null  object
#  11  service_name           290611 non-null  object
#  12  event_type_main        290611 non-null  object
#  13  region_name            290611 non-null  object
# ...

# %%
 # Конвертация для валюты KZT: rubles = revenue (тенге) * (рублей за 100 тенге) / 100
mask_kzt = df['currency_code'].astype(str).str.upper() == 'KZT'
df.loc[mask_kzt, 'revenue_rub'] =(
    df.loc[mask_kzt, 'revenue'] * (df.loc[mask_kzt, 'curs'] / 100.0)
) 
df[df['currency_code'] == 'kzt'].head()
# Out:
#              user_id device_type_canonical  order_id    order_dt  \
# 70   0033403583a55ed                mobile   7850214  2024-09-17
# 89   0040e12d70fae81               desktop   8634925  2024-09-02
# 96   0054b38b2653e6e                mobile   7625522  2024-09-09
# 277  00f4f5244501ce6                mobile    720419  2024-06-11
# 460  01370a0e9c1a7d5                mobile   2229811  2024-06-04
#
#                order_ts currency_code   revenue  tickets_count  \
# 70  2024-09-17 16:52:06           kzt    518.10              4
# 89  2024-09-02 19:49:14           kzt    347.18              3
# 96  2024-09-09 18:06:04           kzt    328.77              4
# 277 2024-06-11 20:15:57           kzt  22021.55              5
# 460 2024-06-04 13:19:47           kzt   7397.66              4
#
#      days_since_prev  event_id                       event_name_code  \
# 70              20.0    559919  f5ec2467-ee48-42f3-89a0-a2d90d1d6fce
# ...

# %% [markdown]
# **Вывод**
#
# Вся выручка приведена к единой валюте — российскому рублю и хранится в столбце revenue_rub.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Небольшой совет:
#
# * Существует довольно удобный метод [where](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.where.html). Мы можем применить его к столбцу и указать условие, которое будем проверять, а также альтернативный вариант значения. Если условие выполняется, то берется значение из столбца, если нет - альтернативное значение. Тогда расчет выручки в рублях будет выглядеть следующим образом:
#
#     ```python
# df['revenue_rub'] = df['revenue'].where(df['currency_code'] == 'rub', df['revenue'] * df['curs'] / 100)
# ```

# %% [markdown]
# ---
#
# **Задача 2.2:**
#
# - Проверьте данные на пропущенные значения. Если выгрузка из SQL была успешной, то пропуски должны быть только в столбце `days_since_prev`.
# - Преобразуйте типы данных в некоторых столбцах, если это необходимо. Обратите внимание на данные с датой и временем, а также на числовые данные, размерность которых можно сократить.
# - Изучите значения в ключевых столбцах. Обработайте ошибки, если обнаружите их.
#     - Проверьте, какие категории указаны в столбцах с номинальными данными. Есть ли среди категорий такие, что обозначают пропуски в данных или отсутствие информации? Проведите нормализацию данных, если это необходимо.
#     - Проверьте распределение численных данных и наличие в них выбросов. Для этого используйте статистические показатели, гистограммы распределения значений или диаграммы размаха.
#
#         Важные показатели в рамках поставленной задачи — это выручка с заказа (`revenue_rub`) и количество билетов в заказе (`tickets_count`), поэтому в первую очередь проверьте данные в этих столбцах.
#
#         Если обнаружите выбросы в поле `revenue_rub`, то отфильтруйте значения по 99 перцентилю.
#
# После предобработки проверьте, были ли отфильтрованы данные. Если были, то оцените, в каком объёме. Сформулируйте промежуточный вывод, зафиксировав основные действия и описания новых столбцов.
#
# ---

# %%
# Пропуски по каждому столбцу
print("Пропуски по каждому столбцу:\n", df.isnull().sum())
# Out:
# Пропуски по каждому столбцу:
#  user_id                      0
# device_type_canonical        0
# order_id                     0
# order_dt                     0
# order_ts                     0
# currency_code                0
# revenue                      0
# tickets_count                0
# days_since_prev          21933
# event_id                     0
# event_name_code              0
# service_name                 0
# event_type_main              0
# region_name                  0
# city_name                    0
# data                         0
# curs                         0
# revenue_rub                  0
# dtype: int64

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
#
# При анализе данных в столбце "количество дней от предыдущей покупки пользователя" я столкнулась с пропусками. Я решила не предпринимать дополнительных действий по их обработке в связи со следующими соображениями:
#
#  - **Наличие пропусков не критично для текущей задачи:**
# В нашем случае, цель анализа — получить общее представление о поведении пользователей и выявить тренды, а не точное моделирование времени между покупками. В таких случаях пропуски могут быть игнорированы, если они не влияют на ключевые метрики.
#  - **Причины пропусков могут быть разнообразными:**
# Пропуски могут возникать по разным причинам, например, у новых пользователей еще не было второй покупки, или данные не зафиксированы из-за технических сбоев. В этом случае, обработка пропусков могла бы ввести искажения, например, заменой пропусков на нулевые значения или средние, что могло бы исказить реальные сценарии.
#  - **Дальнейшие шаги позволяют минимизировать влияние пропусков:**
# При переходе к следующему этапу анализа или моделирования, мы можем учесть наличие пропусков, например, через использование специальных методов обработки пропусков или моделирование с пропущенными значениями. В текущей ситуации, их игнорирование не мешает достижению целей анализа.
#
# **Вывод:**
# Я приняла решение не обрабатывать пропуски в данном столбце, так как их влияние на текущие задачи минимально, и дальнейшие шаги позволяют учитывать их наличие без дополнительных искажений или сложностей. </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Да, всё правильно

# %%
# Преобразование типов данных
# Для числовых: revenue и tickets_count
# Проверка типов
print(df[['revenue_rub', 'tickets_count']].dtypes)
# Out:
# revenue_rub      float64
# tickets_count      int64
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# В единственной или последней строке ячейки кода Юпитера, метод print() не обязателен, в отличии от тренажера

# %%
# Изучение ключевых столбцов
print(df[['revenue_rub', 'tickets_count']].describe())
# Out:
#          revenue_rub  tickets_count
# count  290611.000000  290611.000000
# mean      555.571987       2.754311
# std       875.498172       1.170620
# min       -90.760000       1.000000
# 25%       113.970000       2.000000
# 50%       351.140000       3.000000
# 75%       802.050000       4.000000
# max     81174.540000      57.000000

# %%
# Проверка категорий
for col in ['currency_code', 'region_name', 'service_name', 'event_type_main', 'region_name', 'city_name']:
    value_counts = df[col].value_counts(dropna=False)
    print(f"\nКатегории в столбце {col}:\n{value_counts}")
# Out:
# Категории в столбце currency_code:
# rub    285542
# kzt      5069
# Name: currency_code, dtype: int64
#
# Категории в столбце region_name:
# Каменевский регион          91058
# Североярская область        44049
# Широковская область         16457
# Медовская область           13901
# Озернинский край            10476
#                             ...
# Лесноярский край               19
# Крутоводский регион            18
# Верхозёрский край              11
# Сосноводолинская область       10
# Теплоозёрский округ             7
# Name: region_name, Length: 81, dtype: int64
#
# Категории в столбце service_name:
# Билеты без проблем        63519
# Лови билет!               41124
# Билеты в руки             40343
# Мой билет                 34839
# Облачко                   26642
# Лучшие билеты             17774
# Весь в билетах            16849
# Прачечная                 10273
# Край билетов               6207
# Тебе билет!                5228
# Яблоко                     5039
# ...

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
# Проанализируем наши категориальные признаки и решим, требуют ли они нормализации или специальных преобразований.
#
# Общий вывод о категориальных признаках:
# Категории в столбце `currency_code`:
# У нас две категории: rub (более 285 тысяч), kzt (около 5 тысяч).
# Многоуровневое, но всего 2 значения — отлично подходит для бинарного кодирования или one-hot.
# Нормализация не требуется; важна правильная кодировка.
# Категории в столбце `region_name`:
# 81 уникальный регион.
# Распределение разбросано: крупные регионы (более 90 тысяч), есть очень редкие (по 10-20).
# Количество уникальных значений достаточно большое, но не чрезмерное.
# Нормализация не требуется — это категориальный признак, а не числовой. Важно правильно закодировать.
# Категории в столбце `service_name`:
# Много различных названий (от 4 тысяч до 63 тысяч).
# Распределение неравномерное: есть очень популярные, есть редкие.
# Не обязательно масштабировать.
# Нормализация не требуется.
# Категории в столбце `event_type_main`:
# 6 категорий с явно выраженным балансом (от 11 тысяч до 115 тысяч).
# Масштабировать не нужно.
# Категории в `city_name`:
# Множество городов, некоторые встречаются по 1 разу (самые редкие).
# Для редких городов можно объединить в категорию «другие» или применить target/частотное кодирование.
# Нормализация не требуется.
#
# **Итоговые рекомендации:**
# Нормализация не требуется для категориальных признаков, поскольку они — дискретные категории, а не числовые признаки.
# Важно правильно кодировать эти признаки перед использованием модели.
# Обработка редких категорий:
# Можно объединить редкие категории в одну «другие» для снижения разброса и предотвращения разреженности.
#
# **Заключение:**
# Наши категориальные признаки в порядке и не требуют нормализации. Главное — выбрать подходящий метод кодирования и обработать редкие категории.</div>

# %%
# Гистограммы (для revenue_rub)
plt.figure(figsize=(8,4))
df['revenue_rub'].plot(kind='hist', bins=100)
plt.title('Распределение revenue_rub')
plt.xlabel('revenue_rub')
plt.show()

# Диаграмма размаха для revenue_rub
df.boxplot(column=['revenue_rub'], grid=False)
plt.show()

# Гистограммы (для tickets_count)
plt.figure(figsize=(8,4))
df['tickets_count'].plot(kind='hist', bins=100)
plt.title('Распределение tickets_count')
plt.xlabel('tickets_count')
plt.show()

# Диаграмма размаха для tickets_count
df.boxplot(column=['tickets_count'], grid=False)
plt.show()

# %%
sns.set_theme(style="darkgrid")

# создаем фигуру с двумя графиками
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})

# строим боксплот с явным указанием ключевого аргумента
sns.boxplot(x=df["revenue_rub"], orient="h", ax=ax_box)

# строим гистограмму
sns.histplot(data=df, x="revenue_rub", ax=ax_hist)

# убираем подпись для оси x у боксплота
ax_box.set(xlabel='')

plt.show()

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
# Анализ наличия выбросов в числовых признаках:
#
# **Для признака `revenue_rub`:**
# Максимальное значение — 81174.54 рублей, а среднее — около 555.57 рублей, при этом стандартное отклонение — примерно 875.50. Значение max значительно превышает среднее и межквартильный диапазон (25% — 113.97, 75% — 802.05), что говорит о наличии очень больших выбросов.
#
# **Для признака `tickets_count`:**
# Максимальное значение — 57 билетов, а медиана — 3 билета. Значения выше 20-30 билетов — довольно редки и могут считаться выбросами, особенно учитывая, что среднее всего около 2.75.
#
# ***Предполагаемая природа возникновения выбросов:***
#
# В `revenue_rub` выбросы могут возникать из-за нескольких причин:
# - Ошибки в данных (например, опечатки или неправильный ввод).
# - Аномально крупные заказы или VIP-покупки.
# - Технические сбои, приводящие к неверным значениям.
#
# В `tickets_count` выбросы, скорее всего, связаны с редкими случаями очень крупных групповых покупок или ошибок при вводе данных.
#
# Я решила отбросить выбросы в признаке `revenue_rub`, чтобы уменьшить искажения и повысить качество анализа, а в `tickets_count` — оставить редкие крупные покупки, так как они могут быть важной частью пользовательского поведения и не мешают дальнейшему анализу.</div>

# %%
#Выбросы по 99-й перцентиль для revenue_rub и по ticket_count:
q99_rev = df['revenue_rub'].quantile(0.99)
df = df[df['revenue_rub'] <= q99_rev]

# Аналогично для tickets_count
q99_tk = df['tickets_count'].quantile(0.99)
df = df[df['tickets_count'] <= q99_tk]

#Повторно проверим их после очистки.
print(f'Revenue_rub после очистки:')   
print(df['revenue_rub'].describe())

print(f'Tickets_count после очистки:')
print(df['tickets_count'].describe())

# Дополнительно: пропуски в revenue_rub и tickets_count
print("Пропуски revenue_rub:\n", df['revenue_rub'].isnull().sum())
print("Пропуски tickets_count:\n", df['tickets_count'].isnull().sum())
# Out:
# Revenue_rub после очистки:
# count    287606.000000
# mean        517.791295
# std         511.874111
# min         -90.760000
# 25%         111.690000
# 50%         343.700000
# 75%         788.630000
# max        2628.421739
# Name: revenue_rub, dtype: float64
# Tickets_count после очистки:
# count    287606.000000
# mean          2.735638
# std           1.136194
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max           6.000000
# Name: tickets_count, dtype: float64
# Пропуски revenue_rub:
#  0
# Пропуски tickets_count:
#  0

# %% [markdown]
# **Вывод**
#
# - В результате выполнения задания:
#  -  в исходный датафрейм был добавлен новый столбец `curs` из таблицы курсов казахстанских тенге, и создан новый столбец `revenue_rub`, в котором хранится информация о сумме выручки от заказа, приведенная к единой валюте - российскому рублю.
#
# - В ходе проведения анализа данных:
#  - Как и ожидалось пропущенные значения есть только в столбце `days_since_prev`.
#  - Все типы данных соответствуют формату выводимых занчений. Формат столбца `order_dt` был преобразован в формат `date` на предыдущем шаге, когда было приведение сумма выручки к единой валюте.
#  - При анализе категорий не было выявлено категорий, которые бы обозначали пропуски в данных или отсутствие информации.
#  - Проверка распределения числовых данных в столбце `revenue_rub` показало, что суммы заказов находятся в основном в диапазоне от 0 до 10000, есть выбросы - от 60000 до 80000.
#  - Распределение количества купленных билетов находится в диапазоне от 1 до 10, есть выбросы - количество купленных билетов больше 50.
#  - Так как были обнаружены выбросы, то был произведен процесс фильтрации значений по 99 перцентилю. Было отфильтровано 11527 записей, что составляет  примерно 4% от всех записей.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# * В целом с задачей справились, предобработку провели!
#
#
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * Сейчас ты фиксируешь общие выводы только в конце раздела. Чтобы в работе был понятный сторителлинг, стоит также фиксировать промежуточные свои наблюдения для каждого из шагов: почему мы ничего не стали делать с пропусками и перешли к следующему шагу? Как приняли решение скорректировать тип у тех или иных столбцов? Действительно ли наши категориальные признаки в порядке и не требуют нормализации? Действительно ли в числовых признаках есть выбросы, какова их предполагаемая природа возникновения? Почему мы решили отбросить выбросы в выручке? Почему решили не отбрасывать выбросы в количестве билетов?
#
#
# * Для удобства анализа гистограмму для определенного признака стоит строить рядом с боксплотом, чтобы можно было сопоставлять информацию из них. Можно даже создать пользовательскую функцию, которая будет принимать на вход признак и выводить для него сразу два типа визуализации в одном графике ([пример](https://python-graph-gallery.com/24-histogram-with-a-boxplot-on-top-seaborn/)).
#
#
#
# </div>
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# * Проверить наличие отрицательных значений выручки - возможно, это какие-то возвраты. По-хорошему, их тоже следовало бы исключить, чтобы не завышать количество валидных транзакций на пользователя. Перед этим не забываем проверить, какой процент данных потеряем, не критично ли это.
#
#
# * В задании это не указывается, но по умолчанию важным шагом предварительного анализа и предобработки является проверка на наличие дубликатов, как полных, так и неполных (например, если заказ пользователя задублировался в системе, был создан в нескольких экземплярах с разным `id` и временем заказа). Чтобы не искажать статистические расчеты, от таких наблюдений тоже важно избавляться.
#
#
# * Не изучены категориальные признаки. Тут я бы рекомендовал более тщательнее следить за чистотой данных, проверить категориальные признаки на предмет аномалий и сследить за распределением данных по признакам. Так можно сразу отловить категории с небольшим количеством данных
#
#         # Анализ категориальных значений
#         for column in ['columnname', 'columnname', 'columnname', 'columnname']:
#         print(f"\nColumn: {column}")
#         print("Unique values:", df[column].unique())
#         print("Missing values count:", df[column].isna().sum())
#         print("Value counts:")
#         print(df[column].value_counts(dropna=False), "\n")
#
#
# </div>

# %%
# Шаг 1: Проверяем наличие отрицательных значений
negative_revenue = df[df['revenue_rub'] < 0]

# Шаг 2: Посчитаем процент отрицательных значений
percent_negative = len(negative_revenue) / len(df) * 100

print(f"Общее количество транзакций: {len(df)}")
print(f"Количество транзакций с отрицательной выручкой: {len(negative_revenue)}")
print(f"Процент отрицательных значений: {percent_negative:.2f}%")

# Шаг 3: Просмотр примерных значений
print("\nНекоторые примеры отрицательных значений:")
print(negative_revenue[['revenue_rub']].head())

# Шаг 4: При необходимости — удалить их и проверить, сколько потеряно данных
threshold = 0.05  # например, 5%
if percent_negative > threshold:
    print(f"\nУдаляем отрицательные значения, так как они составляют более {threshold*100}% данных.")
    df_clean = df[df['revenue_rub'] >= 0]
    print(f"Осталось данных: {len(df_clean)}")
else:
    print("\nПроцент отрицательных значений мал, можно оставить все данные как есть.")
# Out:
# Общее количество транзакций: 287606
# Количество транзакций с отрицательной выручкой: 381
# Процент отрицательных значений: 0.13%
#
# Некоторые примеры отрицательных значений:
#       revenue_rub
# 252         -2.37
# 4522        -0.23
# 4549        -0.15
# 8133        -0.62
# 8134        -1.86
#
# Удаляем отрицательные значения, так как они составляют более 5.0% данных.
# Осталось данных: 287225

# %% [markdown]
# Чтобы не искажать статистические расчеты необходимо проверить датасет на дубликаты.

# %%
# 1. Полные дубликаты
full_duplicates = df_clean[df_clean.duplicated(keep=False)]
print(f"Общее количество полных дубликатов (все поля совпадают): {len(full_duplicates)}")

# Удаляем полные дубликаты, оставляя только уникальные
df_no_full_duplicates = df_clean.drop_duplicates()

# 2. Потенциальные дубликаты по ключевым признакам (например, user_id + order_dt + order_id)
key_fields = ['user_id', 'order_dt', 'order_id']
potential_duplicates = df_no_full_duplicates[df_no_full_duplicates.duplicated(subset=key_fields, keep=False)]
print(f"Количество потенциальных дубликатов по ключевым полям: {len(potential_duplicates)}")

# Можно оставить только уникальные заказы по этим ключам
df_no_duplicates = df_no_full_duplicates.drop_duplicates(subset=key_fields)

# Итог
print(f"Общее количество данных после удаления дубликатов: {len(df_no_duplicates)}")
# Out:
# Общее количество полных дубликатов (все поля совпадают): 0
# Количество потенциальных дубликатов по ключевым полям: 0
# Общее количество данных после удаления дубликатов: 287225

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
# Дубликаты в данных не обнаружены </div>

# %%
# Анализ категориальных значений
for column in ['user_id', 'order_dt', 'order_id']:
    print(f"\nColumn: {column}")
    print("Unique values:", df[column].unique())
    print("Missing values count:", df[column].isna().sum())
    print("Value counts:")
    print(df[column].value_counts(dropna=False), "\n")
# Out:
# Column: user_id
# Unique values: ['0002849b70a3ce2' '0005ca5e93f2cf4' '000898990054619' ...
#  'fffcd3dde79eb2c' 'fffeeb3c120cf0b' 'ffff00725179321']
# Missing values count: 0
# Value counts:
# 0beb8fc0c0a9ce1    10168
# 18e9aead0a393e7     4349
# 8187dac4be757a0     4020
# 3ee7dc2e115847f     3789
# 7eb4fc207ecc10f     3698
#                    ...
# a82390584c70049        1
# bbbfc7e6c6ece37        1
# 226048540fe5f04        1
# d53baa6247acfdd        1
# 878321b73821286        1
# Name: user_id, Length: 21847, dtype: int64
#
#
# Column: order_dt
# Unique values: [datetime.date(2024, 8, 20) datetime.date(2024, 7, 23)
#  datetime.date(2024, 10, 6) datetime.date(2024, 7, 13)
#  datetime.date(2024, 10, 4) datetime.date(2024, 10, 23)
#  datetime.date(2024, 8, 15) datetime.date(2024, 9, 29)
#  datetime.date(2024, 10, 15) datetime.date(2024, 6, 20)
#  datetime.date(2024, 6, 21) datetime.date(2024, 6, 25)
#  datetime.date(2024, 7, 25) datetime.date(2024, 6, 17)
# ...

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
#
# **Из предоставленных данных по столбцу `user_id` можно сделать следующие выводы в контексте анализа категориальных значений:**
#
# Высокая уникальность пользователей:
# В датафрейме насчитывается 21 847 уникальных `user_id`, что свидетельствует о большом числе отдельных пользователей.
# Отсутствие пропусков:
# Количество пропущенных значений равно 0, что говорит о полном заполнении этого признака.
# Распределение по пользователям:
# Большинство пользователей совершили лишь по нескольку заказов. Например, есть пользователь с user_id, сделавший 10 168 заказов, что, вероятно, является аномалией или ошибкой, либо свидетельством очень активного клиента.
# Есть и пользователи, сделавшие только по 1 заказу — таких много, что видно из чисел в конце списка.
# Дисбаланс в частотности:
# Значительная часть пользователей совершают очень небольшое количество заказов, тогда как некоторые — очень много. Это классический случай дисбаланса в данных с длинными хвостами.
#
# **Итоговые выводы для анализа категориальных значений:**
# `user_id` является категорическим признаком с высокой степенью разнообразия (много уникальных значений).
# Распределение по количеству заказов у пользователей демонстрирует сильную дисперсию: есть очень активные пользователи и множество пользователей с одним заказом.
# Для дальнейшего анализа важно учитывать такие дисбалансы, возможно, сегментировать пользователей по активности.
# Отсутствие пропусков упрощает анализ и моделирование.
#
# **Из анализа данных по столбцу `order_id` можно сделать следующие выводы:**
#
# Высокая уникальность заказов:
# В датафрейме присутствует большое число уникальных `order_id` — каждый заказ имеет уникальный идентификатор. Судя по количеству значений и их распределению, большинство заказов встречаются по одному разу.
# Отсутствие пропусков:
# Количество пропущенных значений равно 0, что обеспечивает целостность данных по этому признаку.
# Каждый заказ уникален:
# Значения в `order_id` встречаются по одному разу, что говорит о том, что в данных отсутствуют дублирующиеся заказы. Каждый заказ — уникальный объект.
# Нет повторяющихся заказов:
# В данных отсутствуют повторяющиеся `order_id`, что важно для анализа, связанного с обработкой заказов или их статистикой.
#
# **Итоговые выводы для анализа категориальных значений:**
# `order_id` — это уникальный идентификатор заказа, и данные по нему не содержат дубликатов.
# Можно считать, что данные по заказам надежны и не содержат ошибок дублирования.
# В дальнейшем можно использовать `order_id` для точной идентификации каждого заказа, а также для соединения с другими таблицами или аналитическими задачами, связанными с заказами.
#
# **На основании данных по столбцу `order_dt` (дата заказа) можно сделать следующие выводы:**
#
# Основные выводы:
# Отсутствие пропущенных значений:
# Количество пропусков равно 0, что свидетельствует о полном покрытии данных по дате заказа.
# Широкий диапазон дат:
# В данных представлены заказы, сделанные в период с 1 июня 2024 года по 31 октября 2024 года, что указывает на ограниченный временной диапазон анализа.
# Концентрация заказов в определённые даты:
# Наиболее активные дни — 1 и 31 октября 2024 года, с количеством заказов около 7300 и 6000 соответственно.
# Другие популярные даты — 3 и 25 октября, а также 15 октября.
# В целом, многие даты имеют значительный объём заказов, что указывает на устойчивую активность в течение этого периода.
# Распределение заказов по датам:
# В начале периода (июнь 2024) наблюдается снижение количества заказов, примерно до 850-950 заказов в день.
# В конце периода (октябрь 2024) — заметно больше заказов, что может свидетельствовать о росте активности или сезонных трендах.
# Есть явный рост активности в октябре, особенно в последние дни месяца.
# Возможные сезонные или маркетинговые эффекты:
# Высокая активность в октябре может указывать на сезонные распродажи, акции или увеличение спроса.
# Стабильная динамика заказов по датам говорит о регулярных покупках или маркетинговых активностях.
#
# **Итоговые рекомендации:**
# Эти данные подходят для анализа сезонности и определения пиков активности по датам.
# Можно построить временные ряды или графики для визуализации трендов и выявления закономерностей.
# В дальнейшем можно сегментировать по датам для анализа поведения клиентов в разные периоды.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отлично, этап предобработки выполнен корректно

# %% [markdown]
# ---
#
# ### 3. Создание профиля пользователя
#
# В будущем отдел маркетинга планирует создать модель для прогнозирования возврата пользователей. Поэтому сейчас они просят вас построить агрегированные признаки, описывающие поведение и профиль каждого пользователя.
#
# ---
#
# **Задача 3.1.**<div class="alert alert-info"> <b>Комментарии студента:</b> **Анализ профилей пользователей для выявления ключевых признаков поведения**</div>
#
# Постройте профиль пользователя — для каждого пользователя найдите:
#
# - дату первого и последнего заказа;
# - устройство, с которого был сделан первый заказ;
# - регион, в котором был сделан первый заказ;
# - билетного партнёра, к которому обращались при первом заказе;
# - жанр первого посещённого мероприятия (используйте поле `event_type_main`);
# - общее количество заказов;
# - средняя выручка с одного заказа в рублях;
# - среднее количество билетов в заказе;
# - среднее время между заказами.
#
# После этого добавьте два бинарных признака:
#
# - `is_two` — совершил ли пользователь 2 и более заказа;
# - `is_five` — совершил ли пользователь 5 и более заказов.
#
# **Рекомендация:** перед тем как строить профиль, отсортируйте данные по времени совершения заказа.
#
# ---

# %%
# Сначала отсортируем по времени заказа
df_sorted = df.sort_values(['user_id', 'order_dt', 'order_ts'])

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Правильно, что перед агрегацией сортируешь по пользователю и дате, чтобы первый заказ был первым

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
#
# Для того, чтобы понять поведение и характеристики пользователей, выявить последовательности действий и определить особенности каждого клиента необходимо провести анализ профилей пользователей. Это помогает сегментировать аудиторию, предсказать будущие действия и разработать персонализированные стратегии взаимодействия. В данном случае мы собираем информацию о первом заказе, а также о поведении пользователя в течение всего времени взаимодействия, чтобы получить ценные инсайты о его предпочтениях и активности.</div>

# %%
# Группируем по пользователю
#profiles = df_sorted.groupby('user_id').agg(
#    first_order_date=('order_dt', 'min'),
#    last_order_date=('order_dt', 'max'),
#    total_orders=('order_id', 'count'),
#    avg_revenue_per_order=('revenue_rub', 'mean'),
#    avg_tickets_per_order=('tickets_count', 'mean')
#).reset_index()

# %%
df.info()

#profiles.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 287606 entries, 0 to 290610
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   user_id                287606 non-null  object
#  1   device_type_canonical  287606 non-null  object
#  2   order_id               287606 non-null  int64
#  3   order_dt               287606 non-null  object
#  4   order_ts               287606 non-null  datetime64[ns]
#  5   currency_code          287606 non-null  object
#  6   revenue                287606 non-null  float64
#  7   tickets_count          287606 non-null  int64
#  8   days_since_prev        265881 non-null  float64
#  9   event_id               287606 non-null  int64
#  10  event_name_code        287606 non-null  object
#  11  service_name           287606 non-null  object
#  12  event_type_main        287606 non-null  object
#  13  region_name            287606 non-null  object
# ...

# %%
# Получаем данные о первом заказе для каждого пользователя
#first_order = df_sorted.groupby('user_id').first().reset_index()
#first_order = df_sorted.groupby('user_id').agg('first').reset_index()

# Добавляем параметры первого заказа
#profile = profile.merge(
#    first_order[['user_id', 'device_type_canonical', 'region_name', 'service_name', 'event_type_main']],
#    on='user_id', how='left')


# Расчет среднего времени между заказами
# Для этого для каждого пользователя считаем разницу между заказами
#def compute_avg_time_between_orders(group):
#    times = group['order_ts']
#    diffs = times.diff().dropna()
#    if len(diffs) == 0:
#        return pd.Timedelta(0)
#    return diffs.mean()    
    
#avg_time = df_sorted.groupby('user_id').apply(compute_avg_time_between_orders).reset_index()
#avg_time.columns = ['user_id', 'avg_time_between_orders']

# Объединяем
#profile = profile.merge(avg_time, on='user_id', how='left')

# Добавляем бинарные признаки
#profile['is_two'] = (profile['total_orders'] >= 2).astype(int)
#profile['is_five'] = (profile['total_orders'] >= 5).astype(int)

# итог
#print(profile)

# %%
profile = (
    df
    # Сортируем по дате заказа, чтобы взять первые признаки
    .sort_values(by='order_ts')
    # Группируем по user_id
    .groupby('user_id')
    .agg(
        # Первые и последние даты заказа
        first_order_date=('order_dt', 'min'),
        last_order_date=('order_dt', 'max'),
        # Первые признаки заказа
#        first_device=('device_type_canonical', 'first'),
        device_type_canonical=('device_type_canonical', 'first'),
#        first_region_name=('region_name', 'first'),
        region_name=('region_name', 'first'),
#        first_service_name=('service_name', 'first'),
        service_name=('service_name', 'first'),
#        first_event_type=('event_type_main', 'first'),
        event_type_main=('event_type_main', 'first'),
        # Количество заказов
        total_orders=('order_id', 'nunique'),
        # Статистика по заказам
        avg_revenue_per_order =('revenue_rub', 'mean'),
        avg_tickets_per_order =('tickets_count', 'mean'),
        # Среднее между заказами (предположим, что есть столбец days_since_prev)
        avg_time_between_orders=('days_since_prev', 'mean')
    )
    # Создаем признаки о количестве заказов
    .assign(
        is_two=lambda x: x['total_orders'] >= 2,
        is_five=lambda x: x['total_orders'] >= 5
    )
    .reset_index()
)

# %%
profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21847 entries, 0 to 21846
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  21847 non-null  object
#  1   first_order_date         21847 non-null  object
#  2   last_order_date          21847 non-null  object
#  3   device_type_canonical    21847 non-null  object
#  4   region_name              21847 non-null  object
#  5   service_name             21847 non-null  object
#  6   event_type_main          21847 non-null  object
#  7   total_orders             21847 non-null  int64
#  8   avg_revenue_per_order    21847 non-null  float64
#  9   avg_tickets_per_order    21847 non-null  float64
#  10  avg_time_between_orders  13509 non-null  float64
#  11  is_two                   21847 non-null  bool
#  12  is_five                  21847 non-null  bool
# dtypes: bool(2), float64(3), int64(1), object(7)
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Твой способ определения значений категориальных характеристик первого заказа не надежен. Если у пользователя было несколько заказов в первый день, присоединение значений по дате приведет к дублированию записей о пользователе.
#
# В данном случае необходимо группировать и использовать метод агрегации `first`, он берет значение первой записи. Как раз ввиду его использования и следовало отсортировать заказы по времени.
#
# Обрати внимание, что с учетом данной правки могут потребоваться и корректировки в шагах ниже.
#
# </div>
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Также есть довольно удобный метод [assign](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html), позволяющий дополнять таблицу новыми рассчитанными столбцами.
#
#     Тогда создание всего профиля можно будет записать красивым и удобным по структуре кодом.
#
#     <details> <summary> <span style='color:blue' > Развернуть подробнее. </span> </summary>
#
#     ```python
#     profiles = (df
#             # В начале сортируем данные по дате совершения заказа, что найти первые признаки:
#             .sort_values(by='order_ts')
#             # Затем группируем по номеру пользователя и агрегируем данные:
#             .groupby('user_id')
#             .agg(
#                 # Находим первую и последнюю даты заказа:
#                 first_order_dt=('order_dt','min'),
#                 last_order_dt=('order_dt','max'),
#                 # Находим устройства, регион, название билетного партнера и тип мероприятия первого заказа:
#                 first_device=('device_type_canonical','first'),
#                 first_region_name=('region_name','first'),
#                 first_service_name=('service_name','first'),
#                 first_event_type=('event_type_main','first'),
#                 # Подсчитваем количество заказов:
#                 total_orders=('order_id','nunique'),
#                 # Считаем статистику по заказам: средняя стоимость заказа, среднее количество билетов:
#                 avg_revenue_rub=('revenue_rub','mean'),
#                 avg_tickets_count=('tickets_count','mean'),
#                 # Считаем среднее количество дней между покупками:
#                 avg_days_since_prev=('days_since_prev','mean')
#             )
#             # Создаем два признака: совершил ли пользователь 2 / 5 и более заказов:
#             .assign(
#                 is_two = lambda x: x['total_orders'] >= 2,
#                 is_five = lambda x: x['total_orders'] >= 5
#             )
#             .reset_index()
#     )
#     ```
#     </details>
#
#
# * Было бы не лишним оставить пояснение к шагу, почему мы беремся за анализ профилей, а также дать информативное наименование подразделу.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Учтено

# %% [markdown]
# ---
#
# **Задача 3.2.** Прежде чем проводить исследовательский анализ данных и делать выводы, важно понять, с какими данными вы работаете: насколько они репрезентативны и нет ли в них аномалий.
#
# Используя данные о профилях пользователей, рассчитайте:
#
# - общее число пользователей в выборке;
# - среднюю выручку с одного заказа;
# - долю пользователей, совершивших 2 и более заказа;
# - долю пользователей, совершивших 5 и более заказов.
#
# Также изучите статистические показатели:
#
# - по общему числу заказов;
# - по среднему числу билетов в заказе;
# - по среднему количеству дней между покупками.
#
# По результатам оцените данные: достаточно ли их по объёму, есть ли аномальные значения в данных о количестве заказов и среднем количестве билетов?
#
# Если вы найдёте аномальные значения, опишите их и примите обоснованное решение о том, как с ними поступить:
#
# - Оставить и учитывать их при анализе?
# - Отфильтровать данные по какому-то значению, например, по 95-му или 99-му перцентилю?
#
# Если вы проведёте фильтрацию, то вычислите объём отфильтрованных данных и выведите статистические показатели по обновлённому датасету.

# %%
# Общее число пользователей
total_users = len(profile)

# Средняя выручка с одного заказа по всей выборке
mean_revenue = profile['avg_revenue_per_order'].mean()

# Доля пользователей, совершивших 2 и более заказа
prop_two_or_more = profile['is_two'].mean()

# Доля пользователей, совершивших 5 и более заказов
prop_five_or_more = profile['is_five'].mean()

print(f'Общее число пользователей: {total_users}')
print(f'Средняя выручка с одного заказа: {mean_revenue:.2f} руб.')
print(f'Доля пользователей с 2 и более заказов: {prop_two_or_more:.2%}')
print(f'Доля пользователей с 5 и более заказов: {prop_five_or_more:.2%}')
# Out:
# Общее число пользователей: 21847
# Средняя выручка с одного заказа: 544.16 руб.
# Доля пользователей с 2 и более заказов: 61.70%
# Доля пользователей с 5 и более заказов: 29.01%

# %%
print(profile['avg_time_between_orders'].dtype)
# Out:
# float64

# %%
# Статистика по общему числу заказов
orders_stats = profile['total_orders'].describe()
print('Статистика по числу заказов:\n', orders_stats)

# Статистика по среднему количеству билетов в заказе
tickets_stats = profile['avg_tickets_per_order'].describe()
print('Статистика по среднему количеству билетов:\n', tickets_stats)

# Статистика по среднему времени между покупками (в днях)
days_stats = profile['avg_time_between_orders'].describe()
print('Статистика по среднему времени между заказами (дни):\n', days_stats)
# Out:
# Статистика по числу заказов:
#  count    21847.000000
# mean        13.164553
# std        121.581813
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max      10168.000000
# Name: total_orders, dtype: float64
# Статистика по среднему количеству билетов:
#  count    21847.000000
# mean         2.739164
# std          0.902689
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.071429
# max          6.000000
# Name: avg_tickets_per_order, dtype: float64
# Статистика по среднему времени между заказами (дни):
#  count    13509.000000
# mean        15.837199
# std         22.289646
# min          0.000000
# 25%          1.000000
# 50%          8.000000
# 75%         20.333333
# max        148.000000
# Name: avg_time_between_orders, dtype: float64

# %%
# Анализ наличия аномальных значений
# Например, аномально большое число заказов
# Можно посмотреть на перцентили
percentiles = {
    '95th': profile['total_orders'].quantile(0.95),
    '99th': profile['total_orders'].quantile(0.99)
}
print('95-й перцентиль по числу заказов:', percentiles['95th'])
print('99-й перцентиль по числу заказов:', percentiles['99th'])

# Аналогично для количества билетов
tickets_perc_95 = profile['avg_tickets_per_order'].quantile(0.95)
tickets_perc_99 = profile['avg_tickets_per_order'].quantile(0.99)
print('95-й перцентиль по среднему количеству билетов:', tickets_perc_95)
print('99-й перцентиль по среднему количеству билетов:', tickets_perc_99)

# Проверка на выбросы
anomalous_orders = profile[profile['total_orders'] > percentiles['99th']]
anomalous_tickets = profile[profile['avg_tickets_per_order'] > tickets_perc_99]

print(f'Количество аномальных пользователей по заказам (>99 перцентиль): {len(anomalous_orders)}')
print(f'Количество аномальных пользователей по билетам (>99 перцентиль): {len(anomalous_tickets)}')
# Out:
# 95-й перцентиль по числу заказов: 31.0
# 99-й перцентиль по числу заказов: 151.54000000000087
# 95-й перцентиль по среднему количеству билетов: 4.0
# 99-й перцентиль по среднему количеству билетов: 5.0
# Количество аномальных пользователей по заказам (>99 перцентиль): 219
# Количество аномальных пользователей по билетам (>99 перцентиль): 179

# %%
#Решение по аномалиям:
# Можно отфильтровать: например, исключить пользователей с количеством заказов выше 99-перцентиля
# Для этого:
filtered_profile = profile[profile['total_orders'] <= percentiles['99th']]
# Аналогично для билетов
filtered_profile = filtered_profile[filtered_profile['avg_tickets_per_order'] <= tickets_perc_99]

# Пересчитаем статистику для фильтрованных данных
# Итоговые показатели для фильтрованного набора
filtered_total_users = len(filtered_profile)
filtered_orders_stats = filtered_profile['total_orders'].describe()
filtered_tickets_stats = filtered_profile['avg_tickets_per_order'].describe()

print(f'Обновленное число пользователей после фильтрации: {filtered_total_users}')
print('Обновленная статистика по числу заказов:\n', filtered_orders_stats)
print('Обновленная статистика по среднему количеству билетов:\n', filtered_tickets_stats)
# Out:
# Обновленное число пользователей после фильтрации: 21449
# Обновленная статистика по числу заказов:
#  count    21449.000000
# mean         6.519418
# std         14.270130
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max        151.000000
# Name: total_orders, dtype: float64
# Обновленная статистика по среднему количеству билетов:
#  count    21449.000000
# mean         2.713339
# std          0.864453
# min          1.000000
# 25%          2.000000
# 50%          2.750000
# 75%          3.000000
# max          5.000000
# Name: avg_tickets_per_order, dtype: float64

# %% [markdown]
# Проверим как изменилась выручка после фильтрации

# %%
# Средняя выручка до фильтрации
mean_revenue_before = profile['avg_revenue_per_order'].mean()

# Средняя выручка после фильтрации
mean_revenue_after = filtered_profile['avg_revenue_per_order'].mean()

print(f'Средняя выручка до фильтрации: {mean_revenue_before}')
print(f'Средняя выручка после фильтрации: {mean_revenue_after}')
# Out:
# Средняя выручка до фильтрации: 544.1610668323726
# Средняя выручка после фильтрации: 542.2934946517491

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Гистограмма до фильтрации
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(profile['avg_revenue_per_order'], bins=30, kde=True)
plt.title("Распределение выручки ДО фильтрации")

# Гистограмма после фильтрации
plt.subplot(1, 2, 2)
sns.histplot(filtered_profile['avg_revenue_per_order'], bins=30, kde=True)
plt.title("Распределение выручки ПОСЛЕ фильтрации")
plt.show()

# %%
# Диаграмма размаха (boxplot)
plt.figure(figsize=(10, 6))
sns.boxplot(data=[profile['avg_revenue_per_order'], filtered_profile['avg_revenue_per_order']], palette="Set2")
plt.xticks([0, 1], ['До фильтрации', 'После фильтрации'])
plt.ylabel('Выручка')
plt.title('Диаграмма размаха выручки')
plt.show()

# %% [markdown]
# **Вывод**
#
# - В результате выполнения задания был составлен профиль пользователя со всеми требуемыми столбцами.
#
# - В результате иследования данных можно сделать вывод, что данных достаточно по бъему 21847 строк. Наблюдаются аномальные значения в данных о количестве заказов, среднее значение 13, но есть максимальное значение 10168. В данных о среднем количестве билетов аномалий нет.
#     Я приняла решение отфильтровать данные о количестве заказов по 99-му перцентилю. Было отфильтровано порядка 398 записей.
#
# Средняя выручка до и после фильтрации почти не изменилась.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Здесь  все супер, выполнены все необходимые шаги!
#
#
# Как рекомендация, было бы не лишним также проверить, насколько изменилась средняя выручка после удаления выбросов. Посмотреть на распределение данных с помощью гистограмм и диаграмм размаха.

# %% [markdown]
# ---
#
# ### 4. Исследовательский анализ данных
#
# Следующий этап — исследование признаков, влияющих на возврат пользователей, то есть на совершение повторного заказа. Для этого используйте профили пользователей.

# %% [markdown]
# #### 4.1. Исследование признаков первого заказа и их связи с возвращением на платформу
#
# Исследуйте признаки, описывающие первый заказ пользователя, и выясните, влияют ли они на вероятность возвращения пользователя.
#
# ---
#
# **Задача 4.1.1.** Изучите распределение пользователей по признакам.
#
# - Сгруппируйте пользователей:
#     - по типу их первого мероприятия;
#     - по типу устройства, с которого совершена первая покупка;
#     - по региону проведения мероприятия из первого заказа;
#     - по билетному оператору, продавшему билеты на первый заказ.
# - Подсчитайте общее количество пользователей в каждом сегменте и их долю в разрезе каждого признака. Сегмент — это группа пользователей, объединённых определённым признаком, то есть объединённые принадлежностью к категории. Например, все клиенты, сделавшие первый заказ с мобильного телефона, — это сегмент.
# - Ответьте на вопрос: равномерно ли распределены пользователи по сегментам или есть выраженные «точки входа» — сегменты с наибольшим числом пользователей?
#
# ---

# %%
# Создадим сегменты по каждому признаку
# 1. Тип первого мероприятия
segments_event_type = profile['event_type_main']
counts_event_type = segments_event_type.value_counts()
percentages_event_type = segments_event_type.value_counts(normalize=True)

# 2. Устройство первого заказа
segments_device = profile['device_type_canonical']
counts_device = segments_device.value_counts()
percentages_device = segments_device.value_counts(normalize=True)

# 3. Регион первого заказа
segments_region = profile['region_name']
counts_region = segments_region.value_counts()
percentages_region = segments_region.value_counts(normalize=True)

# 4. Билетный оператор первого заказа
segments_operator = profile['service_name']
counts_operator = segments_operator.value_counts()
percentages_operator = segments_operator.value_counts(normalize=True)

# Выводим результаты
print(f'Распределение по типу первого мероприятия:')
print(counts_event_type)
print(f'Доля по типу первого мероприятия:')
print(percentages_event_type)

print(f'Распределение по устройству первого заказа:')
print(counts_device)
print(f'Доля по устройству первого заказа:')
print(percentages_device)

print(f'Распределение по региону первого заказа:')
print(counts_region)
print(f'Доля по региону первого заказа:')
print(percentages_region)

print(f'Распределение по билетному оператору первого заказа:')
print(counts_operator)
print(f'Доля по билетному оператору первого заказа:')
print(percentages_operator)
# Out:
# Распределение по типу первого мероприятия:
# концерты    9643
# другое      5482
# театр       4290
# стендап     1118
# спорт        801
# выставки     418
# ёлки          95
# Name: event_type_main, dtype: int64
# Доля по типу первого мероприятия:
# концерты    0.441388
# другое      0.250927
# театр       0.196366
# стендап     0.051174
# спорт       0.036664
# выставки    0.019133
# ёлки        0.004348
# Name: event_type_main, dtype: float64
# Распределение по устройству первого заказа:
# mobile     18105
# desktop     3742
# Name: device_type_canonical, dtype: int64
# Доля по устройству первого заказа:
# mobile     0.828718
# desktop    0.171282
# Name: device_type_canonical, dtype: float64
# Распределение по региону первого заказа:
# Каменевский регион          7159
# Североярская область        3793
# Широковская область         1238
# Озернинский край             678
# Малиновоярский округ         529
#                             ...
# Залесский край                 2
# ...

# %%
# Столбчатая диаграмма по Типу первого мероприятия
plt.figure(figsize=(10, 6))
ax=counts_event_type.plot(kind='bar')
plt.xlabel('Тип мероприятия')
plt.ylabel('Количество')
plt.title('Распределение по типу первого мероприятия')
# Добавляем подписи значений сверху столбцов
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2, height),
                ha='center', va='bottom')
plt.show()

# %%
# Столбчатая диаграмма по Устройству первого заказа
plt.figure(figsize=(10, 6))
ax=counts_device.plot(kind='bar')
plt.xlabel('Устройство заказа')
plt.ylabel('Количество')
plt.title('Распределение по устройству первого заказа')
# Добавляем подписи значений сверху столбцов
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2, height),
                ha='center', va='bottom')
plt.show()

# %%
# Столбчатая диаграмма по Региону первого заказа
top10 = profile['region_name'].value_counts().head(10)

plt.figure(figsize=(10, 6))
#ax=counts_region.plot(kind='bar')
ax = top10.plot(kind='bar')
plt.xlabel('Регион заказа')
plt.ylabel('Количество')
plt.title('Распределение по региону первого заказа')
# Добавляем подписи значений сверху столбцов
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2, height),
                ha='center', va='bottom')
plt.show()

# %%
# Столбчатая диаграмма по Билетному оператору первого заказа
top10 = profile['service_name'].value_counts().head(10)

plt.figure(figsize=(10, 6))
#ax=counts_operator.plot(kind='bar')
ax = top10.plot(kind='bar')
plt.xlabel('Билетный оператор заказа')
plt.ylabel('Количество')
plt.title('Распределение по билетному оператору первого заказа')
# Добавляем подписи значений сверху столбцов
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{int(height)}', (p.get_x() + p.get_width() / 2, height),
                ha='center', va='bottom')
plt.show()

# %% [markdown]
# **Вывод**
#
#  В ходе выполнения задания мной было построено ряд диаграмм распределения, на основании которых я сделала вывод, что пользователи распределены по сегментам неравномерно. Есть выраженные «точки входа» — сегменты с наибольшим числом пользователей, такие как:
# - в сегменте по **Типу первого мероприятия** большая часть клиентов предпочитает покупать билеты на концерты, это почти на 50% больше чем следующий тип мероприятия Театр.
# - в сегменте по **Устройству первого заказа** основная часть клиентов покупает билеты через ***mobile***
# - в сегменте по **Региону первого заказа** большая доля клиентов находится в Каменевском регионе
# - в сегменте по **Билетному оператору первого заказа** уверенно занимает лидерскую позицию оператор ***Билеты без проблем***

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Алена, обрати, пожалуйста, внимание, что по заданию нам нужно рассчитать не только абсолютные значения, но и доли

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
#
# У меня посчитаны доли: percentages_event_type, percentages_device, percentages_region, percentages_operator, просто я не стала строить по ним графики, подумала что будет много графиков.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
#
# * Можно еще визуализировать полученные данные,
#
# * По выводам хорошо бы показать общую картину: как распределяются пользователи по сегментам, какие группы преобладают, какие встречаются реже и почему так может быть. А уже после этого привести конкретные значения - как подтверждение своих наблюдений.

# %% [markdown]
# ---
#
# **Задача 4.1.2.** Проанализируйте возвраты пользователей:
#
# - Для каждого сегмента вычислите долю пользователей, совершивших два и более заказа.
# - Визуализируйте результат подходящим графиком. Если сегментов слишком много, то поместите на график только 10 сегментов с наибольшим количеством пользователей. Такое возможно с сегментами по региону и по билетному оператору.
# - Ответьте на вопросы:
#     - Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?
#     - Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?
#
# При интерпретации результатов учитывайте размер сегментов: если в сегменте мало пользователей (например, десятки), то доли могут быть нестабильными и недостоверными, то есть показывать широкую вариацию значений.
#
# ---

# %%
# Группируем по event_type_main
result = profile.groupby('event_type_main').agg(
    total_users=('user_id', 'nunique'),
    users_with_2_plus_orders=('is_two', lambda x: x.sum())  # так как is_two=1 для таких пользователей
).reset_index()

# Посчитаем долю
result['share_2_plus'] = result['users_with_2_plus_orders'] / result['total_users']

print(result)
# Out:
#   event_type_main  total_users  users_with_2_plus_orders  share_2_plus
# 0        выставки          418                       269      0.643541
# 1          другое         5482                      3292      0.600511
# 2        концерты         9643                      5994      0.621591
# 3           спорт          801                       450      0.561798
# 4         стендап         1118                       684      0.611807
# 5           театр         4290                      2738      0.638228
# 6            ёлки           95                        53      0.557895

# %%
# Сортируем по доле для лучшей читаемости
result_sorted = result.sort_values('share_2_plus', ascending=False)

# Построение столбчатой диаграммы
plt.figure(figsize=(12, 6))
plt.bar(result_sorted['event_type_main'], result_sorted['share_2_plus'], color='skyblue')

# Добавляем подписи и заголовок
plt.xlabel('Тип мероприятия')
plt.ylabel('Доля пользователей с 2 и более заказами')
plt.title('Доля пользователей с 2+ заказами по типам мероприятий')
plt.xticks(rotation=45, ha='right')

# Добавляем подписи значений сверху столбцов
for idx, val in enumerate(result_sorted['share_2_plus']):
    plt.text(idx, val + 0.01, f"{val:.2%}", ha='center', va='bottom')
    
plt.tight_layout()
plt.show()

# %%
# Группируем по device_type_canonical
result2 = profile.groupby('device_type_canonical').agg(
    total_users2=('user_id', 'nunique'),
    users_with_2_plus_orders2=('is_two', lambda x: x.sum())  # так как is_two=1 для таких пользователей
).reset_index()

# Посчитаем долю
result2['share_2_plus'] = result2['users_with_2_plus_orders2'] / result2['total_users2']

# Сортируем по доле для лучшей читаемости
result_sorted2 = result2.sort_values('share_2_plus', ascending=False)

# Построение столбчатой диаграммы
plt.figure(figsize=(12, 6))
plt.bar(result_sorted2['device_type_canonical'], result_sorted2['share_2_plus'], color='skyblue')

# Добавляем подписи и заголовок
plt.xlabel('Тип устройства')
plt.ylabel('Доля пользователей с 2 и более заказами')
plt.title('Доля пользователей с 2+ заказами по типам устройства')
plt.xticks(rotation=45, ha='right')

# Добавляем подписи значений сверху столбцов
for idx, val in enumerate(result_sorted2['share_2_plus']):
    plt.text(idx, val + 0.01, f"{val:.2%}", ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Группируем по region_name
result3 = profile.groupby('region_name').agg(
    total_users3=('user_id', 'nunique'),
    users_with_2_plus_orders3=('is_two', lambda x: x.sum())  # так как is_two=1 для таких пользователей
).reset_index()

# Посчитаем долю
result3['share_2_plus'] = result3['users_with_2_plus_orders3'] / result3['total_users3']

# Сортируем по доле для лучшей читаемости
top_10_3 = result3.sort_values('share_2_plus', ascending=False).head(10)

# Построение столбчатой диаграммы
plt.figure(figsize=(12, 6))
plt.bar(top_10_3['region_name'], top_10_3['share_2_plus'], color='skyblue')

# Добавляем подписи и заголовок
plt.xlabel('Регион')
plt.ylabel('Доля пользователей с 2 и более заказами')
plt.title('Доля пользователей с 2+ заказами по регионам')
plt.xticks(rotation=45, ha='right')

# Добавляем подписи значений сверху столбцов
for idx, val in enumerate(top_10_3['share_2_plus']):
    plt.text(idx, val + 0.01, f"{val:.2%}", ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
# Группируем по service_name
result4 = profile.groupby('service_name').agg(
    total_users4=('user_id', 'nunique'),
    users_with_2_plus_orders4=('is_two', lambda x: x.sum())  # так как is_two=1 для таких пользователей
).reset_index()

# Посчитаем долю
result4['share_2_plus'] = result4['users_with_2_plus_orders4'] / result4['total_users4']

# Сортируем по доле для лучшей читаемости
top_10_4 = result4.sort_values('share_2_plus', ascending=False).head(10)

# Построение столбчатой диаграммы
plt.figure(figsize=(12, 6))
plt.bar(top_10_4['service_name'], top_10_4['share_2_plus'], color='skyblue')

# Добавляем подписи и заголовок
plt.xlabel('Билетный оператор')
plt.ylabel('Доля пользователей с 2 и более заказами')
plt.title('Доля пользователей с 2+ заказами по билетным операторам')
plt.xticks(rotation=45, ha='right')

# Добавляем подписи значений сверху столбцов
for idx, val in enumerate(top_10_4['share_2_plus']):
    plt.text(idx, val + 0.01, f"{val:.2%}", ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод**
#
# - **Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?**
#     - Чаще всего возвращаются на Яндекс Афишу пользователи, которые приобретают билеты на выставки, через стационарные устройства, которые проживают в Верхозерском крае, и покупают билеты у оператора Зе Бест!
#
# - **Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?**
#   -  Успешные «точки входа» в выборке встречаются в сегменте По регионам, здесь 100% пользователей, которые возвращаются на Яндекс Афишу проживают в Верхозерском крае, и в сегменте по Билетным операторам - здесь 100% клиентов приобретают билеты у оператора Зе Бест!

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# * Можно создать пользовательскую функцию, чтобы не прописывать практически один и тот же код несколько раз
#
#         def segment_summary(df, column):
#         seg = (df.groupby(column).agg(users_count=('user_id', 'nunique')) .reset_index().sort_values('users_count', ascending=False))
#         seg['users_share'] = (seg['users_count'] / seg['users_count'].sum() *100)
#         seg['users_share'] = seg['users_share'].round(2)
#         return seg
#
#
# * По выводам хорошо бы показать общую картину: как распределяются пользователи по сегментам, какие группы преобладают, какие встречаются реже и почему так может быть. А уже после этого привести конкретные значения - как подтверждение своих наблюдений.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
#
# **Вывод**
# В результате проведенного анализа, я выяснила что преобладающие сегменты по типу мероприятия с большим числом пользователей (выставки, театры) — вероятно, потому что эти категории более популярны или более доступны.
# Группы с меньшим числом пользователей (ёлки, спорт) — возможно, это нишевые или сезонные события.
# Высокая доля 2+ заказов в некоторых сегментах указывает на лояльность или привлекательность конкретных категорий.
# Причины различий могут быть связаны с ценами, доступностью, сезонностью, маркетингом или культурными особенностями.
#
# Если рассматривать относительно регионов, то Большие регионы с высоким числом пользователей (например, регионы с большим населением) — логично, что там больше всего пользователей.
# Высокая доля 2+ заказов в некоторых регионах показывает лояльность местных клиентов или хорошую работу маркетинга.
# Маленькие регионы с низким числом пользователей и нулевым показателем share_2_plus могут быть сезонными или менее активно используемыми.
#
# Если рассматривать относительно популярности сервисов, то наиболее популярные сервисы привлекают большинство пользователей.
# Высокий показатель share_2_plus говорит о лояльности и повторных покупках.
# Анализ поможет понять, какие сервисы требуют внимания для повышения удержания клиентов.
#
# В результате проведенной аналитики, можно дать ответы на вопросы:
#
# - **Какие сегменты пользователей чаще возвращаются на Яндекс Афишу?**
#     - Чаще всего возвращаются на Яндекс Афишу пользователи, которые приобретают билеты на выставки, через стационарные устройства, которые проживают в Верхозерском крае, и покупают билеты у оператора Зе Бест!
#
# - **Наблюдаются ли успешные «точки входа» — такие сегменты, в которых пользователи чаще совершают повторный заказ, чем в среднем по выборке?**
#   -  Успешные «точки входа» в выборке встречаются в сегменте По регионам, здесь 100% пользователей, которые возвращаются на Яндекс Афишу проживают в Верхозерском крае, и в сегменте по Билетным операторам - здесь 100% клиентов приобретают билеты у оператора Зе Бест!
#     </div>

# %% [markdown]
# ---
#
# **Задача 4.1.3.** Опираясь на выводы из задач выше, проверьте продуктовые гипотезы:
#
# - **Гипотеза 1.** Тип мероприятия влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты.
# - **Гипотеза 2.** В регионах, где больше всего пользователей посещают мероприятия, выше доля повторных заказов, чем в менее активных регионах.
#
# ---

# %%
import numpy as np
# Группируем по event_type_main
result5 = profile.groupby('event_type_main').agg(
    total_users=('user_id', 'nunique'),
    users_with_2_plus=('is_two', lambda x: x.sum())  # так как is_two=1 для таких пользователей
).reset_index()

# Посчитаем долю\n",
result5['share_2_plus'] = result5['users_with_2_plus'] / result5['total_users']

# Количество типов мероприятий
x = np.arange(len(result5))
width = 0.4  # ширина столбцов

# Значения
total_users = result5['total_users']
users_with_2_plus = result5['users_with_2_plus']
share_2_plus = result5['share_2_plus']  # доля клиентов с 2+ заказами (в процентах или в долях)

# Построение графика
plt.figure(figsize=(14, 6))
bars_total = plt.bar(x - width/2, total_users, width, label='Общее количество пользователей', color='lightgray')
bars_2plus = plt.bar(x + width/2, users_with_2_plus, width, label='Пользователи с 2+ заказами', color='skyblue')

# Добавляем подписи значений над столбцами
for bar in bars_total:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + max(total_users)*0.01, f"{int(height)}", ha='center', va='bottom')

for bar in bars_2plus:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + max(users_with_2_plus)*0.01, f"{int(height)}", ha='center', va='bottom')

# Добавляем линию доли клиентов с 2+ заказами
ax2 = plt.gca().twinx()  # создаем вторую ось
ax2.plot(x, share_2_plus, color='red', marker='o', label='Доля с 2+ заказами', linewidth=2)
ax2.set_ylabel('Доля клиентов с 2+ заказами')
ax2.set_ylim(0, 1)  # если доли в диапазоне 0-1, или укажите в процентах 0-100
 
# Добавляем подписи точек
for i, val in enumerate(share_2_plus):
    ax2.text(i, val + 0.02, f"{val:.2%}", ha='center', va='bottom', color='red')

# Общие настройки
plt.xlabel('Тип мероприятия')
plt.ylabel('Количество пользователей')
plt.title('Общее количество пользователей, с 2+ заказами и доля с 2+ заказами по топ-10 типам мероприятий')
plt.xticks(x, result5['event_type_main'], rotation=45, ha='right')

# Легенда для обеих линий
lines, labels = plt.gca().get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
plt.legend(lines + lines2, labels + labels2, loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Группируем по event_type_main
result6 = profile.groupby('region_name').agg(
    total_users=('user_id', 'nunique'),
    users_with_2_plus=('is_two', lambda x: x.sum())  # так как is_two=1 для таких пользователей
).reset_index()

# Посчитаем долю
result6['share_2_plus'] = result6['users_with_2_plus'] / result6['total_users']

# Для примера возьмем только топ-10 по доле пользователей с 2+ заказами
top_10 = result6.sort_values('share_2_plus', ascending=False).head(10)

# Количество типов мероприятий
x = np.arange(len(top_10))
width = 0.4  # ширина столбцов

# Значения
total_users = top_10['total_users']
users_with_2_plus = top_10['users_with_2_plus']
share_2_plus = top_10['share_2_plus']  # доля клиентов с 2+ заказами (в процентах или в долях)

# Построение графика
plt.figure(figsize=(14, 6))
bars_total = plt.bar(x - width/2, total_users, width, label='Общее количество пользователей', color='lightgray')
bars_2plus = plt.bar(x + width/2, users_with_2_plus, width, label='Пользователи с 2+ заказами', color='skyblue')

# Добавляем подписи значений над столбцами
for bar in bars_total:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + max(total_users)*0.01, f"{int(height)}", ha='center', va='bottom')

for bar in bars_2plus:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + max(users_with_2_plus)*0.01, f"{int(height)}", ha='center', va='bottom')

# Добавляем линию доли клиентов с 2+ заказами
ax2 = plt.gca().twinx()  # создаем вторую ось
ax2.plot(x, share_2_plus, color='red', marker='o', label='Доля с 2+ заказами', linewidth=2)
ax2.set_ylabel('Доля клиентов с 2+ заказами')
ax2.set_ylim(0, 1)  # если доли в диапазоне 0-1, или укажите в процентах 0-100

# Добавляем подписи точек
for i, val in enumerate(share_2_plus):
    ax2.text(i, val + 0.02, f"{val:.2%}", ha='center', va='bottom', color='red')

# Общие настройки
plt.xlabel('Регион')
plt.ylabel('Количество пользователей')
plt.title('Общее количество пользователей, с 2+ заказами и доля с 2+ заказами по Регионам')
plt.xticks(x, top_10['region_name'], rotation=45, ha='right')

# Легенда для обеих линий
lines, labels = plt.gca().get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
plt.legend(lines + lines2, labels + labels2, loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Вывод**
#
# **Гипотеза1** не подтвердилась.  Тип мероприятия не влияет на вероятность возврата на Яндекс Афишу: пользователи, которые совершили первый заказ на спортивные мероприятия, не совершают повторный заказ чаще, чем пользователи, оформившие свой первый заказ на концерты. Из графика видно что доля возрата клиентов, приобретающих билеты на концерты 62,16%, а на спортивные мероприятия 56,18%.
#
# **Гипотеза2** не подтвердилась. В наиболее активном районе не самый высокий процент возврата клиентов, всего 67,40%.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# По второй гипотезе можно сопоставить объем выборки с полученными результатом

# %% [markdown]
# ---
#
# #### 4.2. Исследование поведения пользователей через показатели выручки и состава заказа
#
# Изучите количественные характеристики заказов пользователей, чтобы узнать среднюю выручку сервиса с заказа и количество билетов, которое пользователи обычно покупают.
#
# Эти метрики важны не только для оценки выручки, но и для оценки вовлечённости пользователей. Возможно, пользователи с более крупными и дорогими заказами более заинтересованы в сервисе и поэтому чаще возвращаются.
#
# ---
#
# **Задача 4.2.1.** Проследите связь между средней выручкой сервиса с заказа и повторными заказами.
#
# - Постройте сравнительные гистограммы распределения средней выручки с билета (`avg_revenue_rub`):
#     - для пользователей, совершивших один заказ;
#     - для вернувшихся пользователей, совершивших 2 и более заказа.
# - Ответьте на вопросы:
#     - В каких диапазонах средней выручки концентрируются пользователи из каждой группы?
#     - Есть ли различия между группами?
#
# Текст на сером фоне:
#
# **Рекомендация:**
#
# 1. Используйте одинаковые интервалы (`bins`) и прозрачность (`alpha`), чтобы визуально сопоставить распределения.
# 2. Задайте параметру `density` значение `True`, чтобы сравнивать форму распределений, даже если число пользователей в группах отличается.
#
# ---

# %%
# Создаем две группы:
single_order_users = profile[profile['total_orders'] == 1]['avg_revenue_per_order']
returning_users = profile[profile['total_orders'] >= 2]['avg_revenue_per_order']

# Определяем одинаковые bins
bins = 30  # или выберите подходящее число интервалов

# Построение гистограмм
plt.figure(figsize=(10, 6))
plt.hist(single_order_users, bins=bins, density=True, alpha=0.5, label='Один заказ', color='blue')
plt.hist(returning_users, bins=bins, density=True, alpha=0.5, label='2 и более заказов', color='orange')

# Настройка графика
plt.xlabel('Средняя выручка с заказа (руб)')
plt.ylabel('Плотность')
plt.title('Распределение средней выручки с заказа по группам пользователей')
plt.legend()
plt.grid(axis='y', alpha=0.3)

# Добавление текста на сером фоне (можно оформить как блок комментариев)
plt.gca().add_patch(plt.Rectangle((0.0003, 0.0004), 0.0003, 0.0002, color='gray', alpha=0.0003))

plt.tight_layout()
plt.show()

# %%
all_revenue = profile['avg_revenue_per_order'].dropna()

# Определяем минимальное и максимальное значение
min_value = all_revenue.min()
max_value = all_revenue.max()

# Устанавливаем шаг для бинов
step = 30

# Создаем список границ бинов
bins = np.arange(start=np.floor(min_value), stop=np.ceil(max_value) + step, step=step)

# Далее строим гистограмму для каждой группы
single_order_users = profile[profile['total_orders'] == 1]['avg_revenue_per_order'].dropna()
returning_users = profile[profile['total_orders'] >= 2]['avg_revenue_per_order'].dropna()

plt.figure(figsize=(10, 6))
plt.hist(single_order_users, bins=bins, density=True, alpha=0.5, label='Один заказ', color='blue')
plt.hist(returning_users, bins=bins, density=True, alpha=0.5, label='2 и более заказов', color='orange')

plt.xlabel('Средняя выручка с заказа (руб)')
plt.ylabel('Плотность')
plt.title('Распределение средней выручки с заказа по группам пользователей')
plt.legend()
plt.grid(axis='y', alpha=0.3)

# Можно добавить описание
plt.text(0.05, 0.95, 'Границы бинов фиксированы по всему диапазону данных.',
         transform=plt.gca().transAxes,
         fontsize=10,
         verticalalignment='top',
         bbox=dict(boxstyle='round', facecolor='gray', alpha=0.2))

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ответы на вопросы**
# - **1. В каких диапазонах средней выручки концентрируются пользователи из каждой группы?**
# В группе клиентов с одним заказом, большая часть клиенты концентрируются в диапазоне средней выручки - от 0 до 200. В группе клиентов с двумя заказами большая концентрация клиентов сосредоточена в диапазоне средней выручки от 500 до 1000.
# - **2. Есть ли различия между группами?**
# Можно заметить, что группа с одним заказом имеет распределение, сосредоточенное в низких значениях, а группа с повторными — в более высоких. Это говорит о том, что пользователи, совершающие повторные заказы, склонны тратить больше на один заказ.

# %% [markdown]
# ---
#
# **Задача 4.2.2.** Сравните распределение по средней выручке с заказа в двух группах пользователей:
#
# - совершившие 2–4 заказа;
# - совершившие 5 и более заказов.
#
# Ответьте на вопрос: есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?
#
# ---

# %%
# Создаем группы
group_2_4 = profile[(profile['total_orders'] >= 2) & (profile['total_orders'] <= 4)]['avg_revenue_per_order']
group_5_plus = profile[profile['total_orders'] >= 5]['avg_revenue_per_order']

# Определим одинаковые bins
bins = 30  # или выберите подходящее число интервалов

# Построение гистограмм
plt.figure(figsize=(10, 6))
plt.hist(group_2_4, bins=bins, density=True, alpha=0.5, label='2–4 заказа', color='green')
plt.hist(group_5_plus, bins=bins, density=True, alpha=0.5, label='5 и более заказов', color='red')

# Настройка графика
plt.xlabel('Средняя выручка с заказа (руб)')
plt.ylabel('Плотность')
plt.title('Распределение средней выручки с заказа по группам заказов')
plt.legend()
plt.grid(axis='y', alpha=0.3)

# Отметка на сером фоне с рекомендацией
plt.gca().add_patch(plt.Rectangle((0.0007, 0.0008), 0.0003, 0.0002, color='gray', alpha=0.0003))
#plt.text(0.71, 0.82, 
#         \"Рекомендация:\\nИспользуйте одинаковые интервал(ы) и прозрачность,\\nчтобы сравнить формы распределений.\",
#         fontsize=10, va='top')\n",
 
plt.tight_layout()
plt.show()

# %%
# Создаем группы
group_2_4 = profile[(profile['total_orders'] >= 2) & (profile['total_orders'] <= 4)]['avg_revenue_per_order']
group_5_plus = profile[profile['total_orders'] >= 5]['avg_revenue_per_order']

# Объединяем данные для определения диапазона
all_revenue = pd.concat([group_2_4, group_5_plus])

# Определяем минимальное и максимальное значение
min_value = all_revenue.min()
max_value = all_revenue.max()

# Устанавливаем шаг для бинов
step = 30

# Создаем границы бинов с фиксированным шагом по всему диапазону
bins = np.arange(start=np.floor(min_value), stop=np.ceil(max_value) + step, step=step)

# Построение гистограмм
plt.figure(figsize=(10, 6))
plt.hist(group_2_4, bins=bins, density=True, alpha=0.5, label='2–4 заказа', color='green')
plt.hist(group_5_plus, bins=bins, density=True, alpha=0.5, label='5 и более заказов', color='red')

# Настройка графика
plt.xlabel('Средняя выручка с заказа (руб)')
plt.ylabel('Плотность')
plt.title('Распределение средней выручки с заказа по группам заказов')
plt.legend()
plt.grid(axis='y', alpha=0.3)

# Можно оставить или убрать следующую часть, если она не нужна
# Отметка на сером фоне с рекомендацией
# plt.gca().add_patch(plt.Rectangle((0.0007, 0.0008), 0.0003, 0.0002, color='gray', alpha=0.0003))
# plt.text(0.71, 0.82, 
#          "Рекомендация:\nИспользуйте одинаковые интервал(ы) и прозрачность,\nчтобы сравнить формы распределений.",
#          fontsize=10, va='top')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ответ на вопрос**
#
# **Есть ли различия по значению средней выручки с заказа между пользователями этих двух групп?**
#
# Распределения группы с 5+ заказами заметно смещается в диапазон средней цены от 500 до 1000, это указывает на то, что пользователи, совершающие 5+ заказов, в среднем тратят больше на один заказ.
#
# Интуитивно, обычно пользователи с большим числом заказов склонны тратить больше в среднем на заказ, и их распределения могут смещаться вправо по сравнению с группой, совершившей 2–4 заказа.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# * С этой задачей тоже справились!
#
#
# * Плюс за грамотное оформление графиков - заголовок, подписи осей, легенда, поправка на размер выборки (`density`). По выводам тоже все верно подмечено!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
#
#
#
# * Чтобы удобно было сопоставлять доли пользователей по диапазонам цен, можно настроить единый размер бинов (`bins = 30` фиксирует количество бинов, но размер между сегментами будет отличаться, поскольку диапазон значений у них разный). Для этого в `bins` можно передать границы для формирования бинов с шагом: `bins = range(min_value, max_value+1, 30)`, максимальное и минимальное значения при этом определяем на всей выборке, а не отдельно для каждого сегмента.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
# Добавила еще по одному графику. </div>

# %% [markdown]
# ---
#
# **Задача 4.2.3.** Проанализируйте влияние среднего количества билетов в заказе на вероятность повторной покупки.
#
# - Изучите распределение пользователей по среднему количеству билетов в заказе (`avg_tickets_count`) и опишите основные наблюдения.
# - Разделите пользователей на несколько сегментов по среднему количеству билетов в заказе:
#     - от 1 до 2 билетов;
#     - от 2 до 3 билетов;
#     - от 3 до 5 билетов;
#     - от 5 и более билетов.
# - Для каждого сегмента подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы.
# - Ответьте на вопросы:
#     - Как распределены пользователи по сегментам — равномерно или сконцентрировано?
#     - Есть ли сегменты с аномально высокой или низкой долей повторных покупок?
#
# ---

# %%
# Создаем сегменты
bins = [0, 2, 3, 5, profile['avg_tickets_per_order'].max() + 1]
labels = ['1-2', '2-3', '3-5', '5+']
profile['segment'] = pd.cut(profile['avg_tickets_per_order'], bins=bins, labels=labels, right=False)

# Для каждого сегмента подсчитаем:
# - число пользователей
# - долю пользователей с повторными заказами
segment_stats = profile.groupby('segment').agg(
    total_users=('user_id', 'count'),
    repeat_purchasers=('total_orders', lambda x: (x > 1).sum())
).reset_index()

# Рассчитаем долю повторных покупок
segment_stats['repeat_order_share'] = segment_stats['repeat_purchasers'] / segment_stats['total_users']


# Вычисляем среднюю долю повторных покупок по всему набору данных
average_repeat_share = (profile['total_orders'] > 1).mean()

# Построение графика
plt.figure(figsize=(8, 6))
plt.bar(segment_stats['segment'], segment_stats['repeat_order_share'], color='skyblue')
plt.xlabel('Сегменты по среднему количеству билетов в заказе')
plt.ylabel('Доля пользователей с повторной покупкой')
plt.title('Зависимость доли повторных покупок от сегмента среднего количества билетов')
plt.ylim(0, 1)
plt.grid(axis='y', alpha=0.3)

# Добавляем линию среднего значения
ax = plt.gca()
ax.axhline(average_repeat_share, color='red', linestyle='--', linewidth=2, label='Среднее значение')

# Можно добавить легенду
ax.legend()

plt.show()

# %% [markdown]
# **Ответы на вопросы:**
#
# **1.Как распределены пользователи по сегментам — равномерно или сконцентрировано?**
# Пользователи распределены неравномерно, наибольшая доля повторных покупок в сегменте 2-3 билета
#
# **2.Есть ли сегменты с аномально высокой или низкой долей повторных покупок?**
# Аномально высоких или низких долей не наблюдается.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Грамотное использование параметра ` right=False`. Левая граница включена, правая исключена
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Было бы неплохо для наглядности добавить графики со линией среднего значения (axline),

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
# Добавила на график линию среднего значения. </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Молодец!

# %% [markdown]
# ---
#
# #### 4.3. Исследование временных характеристик первого заказа и их влияния на повторные покупки
#
# Изучите временные параметры, связанные с первым заказом пользователей:
#
# - день недели первой покупки;
# - время с момента первой покупки — лайфтайм;
# - средний интервал между покупками пользователей с повторными заказами.
#
# ---
#
# **Задача 4.3.1.** Проанализируйте, как день недели, в которой была совершена первая покупка, влияет на поведение пользователей.
#
# - По данным даты первого заказа выделите день недели.
# - Для каждого дня недели подсчитайте общее число пользователей и долю пользователей, совершивших повторные заказы. Результаты визуализируйте.
# - Ответьте на вопрос: влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?
#
# ---

# %%
# 1. Выделяем день недели
profile['first_order_date'] = pd.to_datetime(profile['first_order_date']).dt.day_name()

# 2. Для каждого дня недели подсчитаем:
# - общее число пользователей
# - число пользователей с повторными заказами
segment_stats = profile.groupby('first_order_date').agg(
    total_users=('user_id', 'count'),
    repeat_users=('total_orders', lambda x: (x > 1).sum())
).reset_index()

# Расчет доли повторных заказов
segment_stats['repeat_order_share'] = segment_stats['repeat_users'] / segment_stats['total_users']

# 3. Визуализация
plt.figure(figsize=(10, 6))
plt.bar(segment_stats['first_order_date'], segment_stats['repeat_order_share'], color='coral')
plt.xlabel('День недели первой покупки')
plt.ylabel('Доля пользователей с повторной покупкой')
plt.title('Влияние дня недели первой покупки на вероятность возврата клиента')
plt.ylim(0, 1)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# **Ответ на вопрос**
#
# **Влияет ли день недели, в которую совершена первая покупка, на вероятность возврата клиента?**
# На графике видно, что доли повторных покупок не сильно отличаются в зависимости от дня, следовательно можно сказать, что день недели, в который была совершена первая покупка, не влияет на вероятность возврата клиента.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Когда планируют досуг, но возвращаемость остаётся примерно одинаковой — это говорит о том, что день недели первой покупки не влияет на лояльность, а повторное использование сервиса определяется скорее качеством опыта и интересом к мероприятиям

# %% [markdown]
# ---
#
# **Задача 4.3.2.** Изучите, как средний интервал между заказами влияет на удержание клиентов.
#
# - Рассчитайте среднее время между заказами для двух групп пользователей:
#     - совершившие 2–4 заказа;
#     - совершившие 5 и более заказов.
# - Исследуйте, как средний интервал между заказами влияет на вероятность повторного заказа, и сделайте выводы.
#
# ---

# %%
# Разделение на группы по количеству заказов
group_2_4 = profile[profile['total_orders'].between(2, 4)]
group_5_plus = profile[profile['total_orders'] >= 5]

# Вычисление средних значений и доли пользователей с повторными заказами
def compute_stats(group):
    mean_days = group['avg_time_between_orders'].mean()
    repeat_order_ratio = len(group) / len(profile[profile['total_orders'] > 1])  # или можно считать отдельно
    return mean_days, repeat_order_ratio

mean_days_2_4, repeat_ratio_2_4 = compute_stats(group_2_4)
mean_days_5_plus, repeat_ratio_5_plus = compute_stats(group_5_plus)

print(f"Группа 2-4 заказов: среднее время между покупками = {mean_days_2_4:.2f} дней, доля с повторным заказом = {repeat_ratio_2_4:.2%}")
print(f"Группа 5+ заказов: среднее время между покупками = {mean_days_5_plus:.2f} дней, доля с повторным заказом = {repeat_ratio_5_plus:.2%}")
# Out:
# Группа 2-4 заказов: среднее время между покупками = 21.31 дней, доля с повторным заказом = 52.99%
# Группа 5+ заказов: среднее время между покупками = 9.58 дней, доля с повторным заказом = 47.01%

# %%
# Создаем группы
group_2_4 = profile[profile['total_orders'].between(2, 4)]
group_5_plus = profile[profile['total_orders'] >= 5]

# Определяем диапазон значений для бинов
all_data = pd.concat([group_2_4['avg_time_between_orders'], group_5_plus['avg_time_between_orders']])
min_value = all_data.min()
max_value = all_data.max()

# Создаем одинаковые границы бинов
bins = np.linspace(min_value, max_value, 30)  # 30 бинов, можно изменить число

# Построение наложенных гистограмм
plt.figure(figsize=(10, 6))
plt.hist(group_2_4['avg_time_between_orders'], bins=bins, density=True, alpha=0.5, label='Группа 2-4 заказов', color='blue')
plt.hist(group_5_plus['avg_time_between_orders'], bins=bins, density=True, alpha=0.5, label='Группа 5+ заказов', color='orange')

# Настройка графика
plt.xlabel('Среднее время между заказами (дни)')
plt.ylabel('Плотность')
plt.title('Наложенные гистограммы времени между заказами по группам')
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# **Вывод**
#
# Пользователи с меньшим средним интервалом времени между покупками 9,17 дней реже совершают повторные покупки, доля возврата клиентов 47,01%

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# <b>Отлично ✅:</b> По расчетам все верно!
#
# </div>
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# <b>Рекомендации💡:</b>  Важно иметь в виду, что среднее значение довольно сильно зависит от характера распределения, если есть какие-то сильные выбросы, они могут утянуть среднее значение вверх, хотя основаня масса значений будет гораздо ниже. Поэтому здесь важно было бы построить в том числе гистограммы, наложить их друг на друга (как мы это делали при сравнении выручки), чтобы видеть всю картину в данных.
#
# </div>

# %% [markdown]
# ---
#
# #### 4.4. Корреляционный анализ количества покупок и признаков пользователя
#
# Изучите, какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок. Для этого используйте универсальный коэффициент корреляции `phi_k`, который позволяет анализировать как числовые, так и категориальные признаки.
#
# ---
#
# **Задача 4.4.1:** Проведите корреляционный анализ:
# - Рассчитайте коэффициент корреляции `phi_k` между признаками профиля пользователя и числом заказов (`total_orders`). При необходимости используйте параметр `interval_cols` для определения интервальных данных.
# - Проанализируйте полученные результаты. Если полученные значения будут близки к нулю, проверьте разброс данных в `total_orders`. Такое возможно, когда в данных преобладает одно значение: в таком случае корреляционный анализ может показать отсутствие связей. Чтобы этого избежать, выделите сегменты пользователей по полю `total_orders`, а затем повторите корреляционный анализ. Выделите такие сегменты:
#     - 1 заказ;
#     - от 2 до 4 заказов;
#     - от 5 и выше.
# - Визуализируйте результат корреляции с помощью тепловой карты.
# - Ответьте на вопрос: какие признаки наиболее связаны с количеством заказов?
#
# ---

# %%
# Получить список всех числовых признаков
#numeric_features = profile.select_dtypes(include=[np.number]).columns.tolist()

# Исключить признаки
#numeric_features.remove('total_orders')
#numeric_features.remove('is_two')
#numeric_features.remove('is_five')

#print("Интервальные признаки:", numeric_features)

exclude_features = ['total_orders', 'is_two', 'is_five']
numeric_features = [feat for feat in numeric_features if feat not in exclude_features]

print("Интервальные признаки:", numeric_features)
# Out:
# Интервальные признаки: ['avg_revenue_per_order', 'avg_tickets_per_order', 'avg_time_between_orders']

# %%
# 1. Расчет корреляции для всего набора данных
# Создаем DataFrame с признаками профиля
#profile_features = profile[numeric_features]

# Добавляем целевую переменную
#profile_features['total_orders'] = profile['total_orders']

# Расчет корреляции (используем корреляцию Пирсона для интервальных данных)
#corr_matrix = profile_features.corr()

# 2. Анализ
#print(corr_matrix['total_orders'])

# Если корреляции малы, делим на сегменты
#segments = {
#    '1_order': profile[profile['total_orders'] == 1],
#    '2_4_orders': profile[profile['total_orders'].between(2, 4)],
#    '5_plus_orders': profile[profile['total_orders'] >= 5]
#}

# 3. Визуализация тепловых карт для каждого сегмента
#for segment_name, segment_df in segments.items():
#    segment_features = segment_df[numeric_features]
#    segment_features['total_orders'] = segment_df['total_orders']
#    corr = segment_features.corr()
   
#    plt.figure(figsize=(8,6))
#    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
#    plt.title(f'Корреляционная матрица для сегмента: {segment_name}')
#    plt.show()

# %%
# Создаем DataFrame с признаками профиля
profile_features = profile[numeric_features].copy()
# Добавляем целевую переменную
profile_features.loc[:, 'total_orders'] = profile['total_orders']

# В цикле по сегментам
for segment_name, segment_df in segments.items():
    segment_features = segment_df[numeric_features].copy()
    segment_features.loc[:, 'total_orders'] = segment_df['total_orders']
    corr = segment_features.corr()
   
    plt.figure(figsize=(8,6))
    sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
    plt.title(f'Корреляционная матрица для сегмента: {segment_name}')
    plt.show()

# %%
# Создаем DataFrame с признаками профиля
profile_features = profile[numeric_features].copy()
# Добавляем целевую переменную
profile_features.loc[:, 'total_orders'] = profile['total_orders']

# Расчет корреляции для всего набора данных
corr_matrix = profile_features.corr()

# Получение корреляций с 'total_orders'
corr_with_target = corr_matrix['total_orders'].drop('total_orders')

# Сортируем по абсолютной значимости
sorted_corr = corr_with_target.abs().sort_values(ascending=False)

print("Признаки, наиболее связанные с количеством заказов:")

for feature in sorted_corr.index:
    corr_value = corr_with_target[feature]
    # Определяем степень связи
    if abs(corr_value) > 0.7:
        strength = "сильная"
    elif abs(corr_value) > 0.3:
        strength = "умеренная"
    else:
        strength = "слабая"
    print(f"{feature}: корреляция = {corr_value:.2f} ({strength})")
# Out:
# Признаки, наиболее связанные с количеством заказов:
# avg_time_between_orders: корреляция = -0.07 (слабая)
# avg_revenue_per_order: корреляция = -0.01 (слабая)
# avg_tickets_per_order: корреляция = -0.00 (слабая)

# %% [markdown]
# **Ответ на вопрос**
#
# **Какие признаки наиболее связаны с количеством заказов?**
# Все интервальные признаки связаны с количеством заказов: это и средняя выручка от заказов, и среднее количество билетов, и среднее количество дней между заказами.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Отсутствует интерпретация корреляции. Насколько они связаны? Как сильно?

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
#
# **Интерпритация:**
# `avg_time_between_orders` (среднее время между заказами) — корреляция примерно -0.07
# Это очень слабая отрицательная связь. Значит, увеличение среднего времени между заказами практически не связано с изменением количества заказов. Можно сказать, что этот признак в текущем виде не сильно влияет на число заказов.
# `avg_revenue_per_order` (средний доход на заказ) — корреляция примерно -0.01
# Очень слабая или практически отсутствующая связь. Этот признак почти не связан с количеством заказов, и его влияние, скорее всего, можно игнорировать при анализе или моделировании.
# `avg_tickets_per_order` (среднее количество чеков/товаров на заказ) — корреляция примерно 0.00
# Полностью отсутствует связь. Этот признак не влияет на число заказов.
#
# **Общие выводы:**
#
# На основе этих коэффициентов можно сказать, что ни один из этих признаков не является существенным для количества заказов.
# Для дальнейшего анализа рекомендуется сосредоточиться на других признаках, которые могут иметь более сильную корреляцию.
# Также, слабая корреляция может означать, что эти признаки связаны с количеством заказов нелинейно или через сложные взаимодействия, которые корреляционный анализ не захватывает. В таком случае, стоит применить другие методы или расширить набор признаков.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# С этим заданием тоже справились!

# %% [markdown]
# ### 5. Общий вывод и рекомендации
#
# В конце проекта напишите общий вывод и рекомендации: расскажите заказчику, на что нужно обратить внимание. В выводах кратко укажите:
#
# - **Информацию о данных**, с которыми вы работали, и то, как они были подготовлены: например, расскажите о фильтрации данных, переводе тенге в рубли, фильтрации выбросов.
# - **Основные результаты анализа.** Например, укажите:
#     - Сколько пользователей в выборке? Как распределены пользователи по числу заказов? Какие ещё статистические показатели вы подсчитали важным во время изучения данных?
#     - Какие признаки первого заказа связаны с возвратом пользователей?
#     - Как связаны средняя выручка и количество билетов в заказе с вероятностью повторных покупок?
#     - Какие временные характеристики влияют на удержание (день недели, интервалы между покупками)?
#     - Какие характеристики первого заказа и профиля пользователя могут быть связаны с числом покупок согласно результатам корреляционного анализа?
# - Дополните выводы информацией, которая покажется вам важной и интересной. Следите за общим объёмом выводов — они должны быть компактными и ёмкими.
#
# В конце предложите заказчику рекомендации о том, как именно действовать в его ситуации. Например, укажите, на какие сегменты пользователей стоит обратить внимание в первую очередь, а какие нуждаются в дополнительных маркетинговых усилиях.

# %% [markdown]
# **Итоговый вывод**
#
# В процессе работы над проектом я работала с информацией о заказах билетов через Ядекс Афиша. Исходный датасет содержал 14 столбцов и 290611 строк. В исходном датафрейме содержалась информация о сумме выручки от продажи билетов, которая была представлена не только в российских рублях, но и в казахстанских тенге. В ходе выполнения заданий мной была проведена процедура перевода тенге  рубли, в следствии чего в датафрейме появился новый столбец `revenue_rub`, который хранит сумму выручки в рублях.
# Также при исследовании данных были выявлены выбросы в количестве купленных билетов, в результате работы с выбросами был произведен процесс фильтрации значений по 99 перцентилю. Было отфильтровано 11527 записей, что составляет  примерно 4% от всех записей.
#
# В результате проведенного анализа было выявлено, что:
#  - Количество клиентов, участвующих в исследовании составило 21847.
#  - Все интервальные признаки связаны с количеством заказов: это и средняя выручка от заказов, и среднее количество билетов, и среднее количество дней между заказами.
#  - Пользователи, совершающие повторные заказы, склонны тратить больше денег на один заказ.
#  - Сегменты 2-3 билета имеют более высокую вероятность повторных покупок, а вот сегмент 5+ имеет низкую вероятность повторных покупок.
#  - День недели, в который была совершена первая покупка, не влияет на вероятность возврата клиента.
#  - Пользователи с меньшим средним интервалом времени между покупками реже совершают повторные покупки.
#  - Чаще всего возвращаются на Яндекс Афишу пользователи, которые приобретают билеты на выставки, через стационарные устройства, которые проживают в Верхозерском крае, и покупают билеты у оператора Зе Бест!"

# %% [markdown]
# **Рекомендации для повышения эффективности работы с клиентской базой**
#
# Фокус на сегментах с высокой вероятностью повторных покупок (2–3 билета)
# Эти сегменты показывают более высокую вероятность возврата. Рекомендуется усилить маркетинговые активности (например, персонализированные предложения, скидки или программы лояльности), чтобы стимулировать повторные покупки именно в этих группах.
# Особое внимание к сегменту с 5 и более билетами
# Этот сегмент демонстрирует низкую вероятность повторных заказов, несмотря на высокий уровень затрат. Следует изучить причины снижения повторных покупок (например, качество сервиса, цена, ассортимент) и внедрить меры по улучшению клиентского опыта.
# Работа с пользователями, совершающими повторные заказы и склонными тратить больше
# Такие клиенты — потенциальные лояльные и ценные. Для них стоит создавать индивидуальные предложения, программы лояльности и дополнительные услуги, чтобы повысить их удержание и средний чек.
# Улучшение коммуникации с пользователями, совершающими покупки через стационарные устройства и в Верхозерском крае
# Эти сегменты показывают высокую активность. Можно развивать таргетированные кампании, предлагать эксклюзивные акции и информационные материалы для усиления вовлеченности.
# Анализ поведенческих факторов
# Пользователи, совершающие покупки с меньшим интервалом между заказами, реже повторяют покупки. Следует мотивировать их возвращаться чаще — например, через напоминания, скидки или бонусы за регулярность.
# Рассмотрите возможность персонализированных предложений по дням недели
# Так как день первой покупки не влияет на возврат, особый акцент можно делать на другие факторы (например, время, канал покупки, регион), чтобы увеличить шанс повторных заказов.
# Дополнительные маркетинговые усилия
# Для сегментов с низкой вероятностью повторных покупок (например, 5+ билетов или определённые регионы) рекомендуется проводить дополнительные кампании по удержанию, например, программы лояльности, персонализированные скидки, опросы для выявления причин низкой активности.
#
# **Итог:**
#
# В первую очередь сосредоточьтесь на сегментах с 2–3 билетами и пользователях с высокой активностью.
# Для сегментов с низкой повторной активностью — разрабатывайте дополнительные меры по стимулированию возврата.
# Используйте данные о предпочтениях по каналам и регионам для таргетирования маркетинговых кампаний.
# Постоянно мониторьте поведенческие показатели и корректируйте стратегии.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С задачей справились! Все ключевые моменты отражены, что позволяет быстро ознакомиться с процессом работы и результатом, не вдаваясь в технический детали. Здорово, что завершаешь проект рекомендациями, основанные на выявленных закономерностях. Предложенные рекомендации логично следуют из анализа и могут быть непосредственно реализованы в маркетинговых стратегиях подогревания и удержания.
#
# </div>

# %% [markdown]
# ### 6. Финализация проекта и публикация в Git
#
# Когда вы закончите анализировать данные, оформите проект, а затем опубликуйте его.
#
# Выполните следующие действия:
#
# 1. Создайте файл `.gitignore`. Добавьте в него все временные и чувствительные файлы, которые не должны попасть в репозиторий.
# 2. Сформируйте файл `requirements.txt`. Зафиксируйте все библиотеки, которые вы использовали в проекте.
# 3. Вынести все чувствительные данные (параметры подключения к базе) в `.env`файл.
# 4. Проверьте, что проект запускается и воспроизводим.
# 5. Загрузите проект в публичный репозиторий — например, на GitHub. Убедитесь, что все нужные файлы находятся в репозитории, исключая те, что в `.gitignore`. Ссылка на репозиторий понадобится для отправки проекта на проверку. Вставьте её в шаблон проекта в тетрадке Jupyter Notebook перед отправкой проекта на ревью.

# %% [markdown]
# **Вставьте ссылку на проект в этой ячейке тетрадки перед отправкой проекта на ревью.**
#
# https://ds-practicum.gitlab.yandexcloud.net/s26725875/yandex-afisha_korkinaan.git
#
# P.S. я сделала проект в GitLab, у меня никак не получается зарегистрироваться в GitHub, и инструкция по устранению ошибок не помогла.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Оххх, к сожалению тут не смогу помочь (думаю тут поможет наставник). Но сейчас, к сожалению, у меня отсутствует доступ.
#
# Кстати, лайфхак - можно проверить корректность ссылки перед отправкой с помощью режима инкогнито в любом браузере ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
# Не могу пока победить GitHub. Но Вы могли бы пожалуйста пока проверить корректировки в расчетах, а я еще сегодня помучаю GitHub или GitLab.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Договорились!)

# %% [markdown]
#    <div class="alert alert-info"> <b>Комментарии студента2:</b>
# Наконец-то победила GitHub. Добавляю ссылку
#    https://github.com/korkinaalyona/Afisha_Yandex.git   </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера 3__
#
#
# Алёна, смотри: нужно выложить файл формата ipynb (без чувствительных данных). Чтобы увидеть копию твоего проекта =)
#
#
# <div class="alert alert-block alert-warning">📝
#
# __Комментарий от ревьюера 3__
#
#
# Можно еще добавить информацию в readme.md, где указать ключевые моменты проекта. Или зафиксировать цели и полученные выводы.
